# %% [markdown]
# # Pre-processing of "COVID-19" IntAct MITAB 2.5 tabular data
#
# This notebook has the purpose to pre-process **MITAB 2.5** tabular data to make them more human-readable and usable to generate NDEx networks using our Python TSV loader.

# %% [markdown]
# ## Network Structure
#
# ### Nodes
# The __name__ will be an official gene symbol or other short human-readable name (for non-protein nodes).
#
# The __represent__ will be an official identifier as specified in the **"ID(s) interactor A/B"** columns.
#
# __Attribute 1 = alias__ This will be a list of strings with the content contained in the **"Alias(es) interactor A/B"** columns.
#
# __Attribute 2 = taxid__ This will be a string with the content of the **"Taxid interactor A/B"** columns.
#
# __Attribute 3 = type__ This will be a string with the content of the **"Type(s) interactor A/B"** columns.
#
# ### Edges
#
# Edges will have the default predicate **interacts-with**
#
# Edges will also have several attributes from the following columns in the original data set:
#
# > 'Interaction detection method(s)'
#
# > 'Publication 1st author(s)'
#
# > 'Publication Identifier(s)'
#
# > 'Interaction type(s)'
#
# > 'Confidence value(s)'
#
# > 'Biological role(s) interactor A'
#
# > 'Biological role(s) interactor B'
#
# > 'Experimental role(s) interactor A'
#
# > 'Experimental role(s) interactor B'
#
# > "Expansion method(s)"
#
# > "Interaction Xref(s)"
#
# > "Interaction annotation(s)"
#
# > "Host organism(s)"
#
# > "Interaction parameter(s)"

# %% [markdown]
# ## Packages and data import

# %%
import pandas as pd

# %%
original_data = pd.read_csv('annot__dat_mitab2_5.txt', sep='\t')
original_data.head(3)
# Out:
#   #ID(s) interactor A ID(s) interactor B  \
# 0    uniprotkb:P31809   uniprotkb:P11224
# 1    uniprotkb:P11224   uniprotkb:P11224
# 2    uniprotkb:P11224   uniprotkb:P11224
#
#                              Alt. ID(s) interactor A  \
# 0  intact:EBI-8663470|uniprotkb:Q61353|intact:MIN...
# 1               intact:EBI-16196052|uniprotkb:O39227
# 2               intact:EBI-16196052|uniprotkb:O39227
#
#                 Alt. ID(s) interactor B  \
# 0  intact:EBI-16196052|uniprotkb:O39227
# 1  intact:EBI-16196052|uniprotkb:O39227
# 2  intact:EBI-16196052|uniprotkb:O39227
#
#                               Alias(es) interactor A  \
# 0  psi-mi:ceam1_mouse(display_long)|uniprotkb:Cea...
# 1  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 2  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
#
#                               Alias(es) interactor B  \
# 0  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 1  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 2  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
#
#                Interaction detection method(s) Publication 1st author(s)  \
# 0  psi-mi:"MI:1247"(microscale thermophoresis)       Walls et al. (2016)
# 1           psi-mi:"MI:0067"(light scattering)       Walls et al. (2016)
# 2          psi-mi:"MI:0071"(molecular sieving)       Walls et al. (2016)
#
#                            Publication Identifier(s)  \
# 0  pubmed:26855426|doi:10.1038/nature16988|imex:I...
# 1  pubmed:26855426|doi:10.1038/nature16988|imex:I...
# 2  pubmed:26855426|doi:10.1038/nature16988|imex:I...
#
#                                   Taxid interactor A  ...  \
# 0       taxid:10090(mouse)|taxid:10090(Mus musculus)  ...
# 1  taxid:11142(cvma5)|taxid:11142("Murine coronav...  ...
# 2  taxid:11142(cvma5)|taxid:11142("Murine coronav...  ...
#
#                  Checksum(s) interactor A  \
# 0  rogid:TVzltAt+4VNWHR+xzvc8oHRwQ1010090
# 1  rogid:6rg8ivahgyrx/wjATOTsFDqOrDw11142
# 2  rogid:6rg8ivahgyrx/wjATOTsFDqOrDw11142
#
#                  Checksum(s) interactor B            Interaction Checksum(s)  \
# 0  rogid:6rg8ivahgyrx/wjATOTsFDqOrDw11142  rigid:Y99xRD1y8eE2/yVdAd9yAjVKJ9Y
# 1  rogid:6rg8ivahgyrx/wjATOTsFDqOrDw11142  rigid:5rNkJ7rt9fT0v8b81I4UVRcB8cI
# 2  rogid:6rg8ivahgyrx/wjATOTsFDqOrDw11142  rigid:5rNkJ7rt9fT0v8b81I4UVRcB8cI
#
#   Negative            Feature(s) interactor A  \
# 0    False   sufficient binding region:35-142
# 1    False  sufficient binding region:15-1231
# 2    False  sufficient binding region:15-1231
#
#              Feature(s) interactor B Stoichiometry(s) interactor A  \
# 0  sufficient binding region:15-1231                             -
# 1  sufficient binding region:15-1231                             -
# 2  sufficient binding region:15-1231                             -
#
#   Stoichiometry(s) interactor B          Identification method participant A  \
# 0                             -  psi-mi:"MI:0396"(predetermined participant)
# 1                             0  psi-mi:"MI:0396"(predetermined participant)
# 2                             0  psi-mi:"MI:0396"(predetermined participant)
#
#            Identification method participant B
# 0  psi-mi:"MI:0396"(predetermined participant)
# 1  psi-mi:"MI:0396"(predetermined participant)
# 2  psi-mi:"MI:0396"(predetermined participant)
#
# [3 rows x 42 columns]

# %% [markdown]
# ## Selection of data subset to use

# %%
#Get all column headers as list

original_headers = original_data.columns.values.tolist()
print(original_headers)
# Out:
# ['#ID(s) interactor A', 'ID(s) interactor B', 'Alt. ID(s) interactor A', 'Alt. ID(s) interactor B', 'Alias(es) interactor A', 'Alias(es) interactor B', 'Interaction detection method(s)', 'Publication 1st author(s)', 'Publication Identifier(s)', 'Taxid interactor A', 'Taxid interactor B', 'Interaction type(s)', 'Source database(s)', 'Interaction identifier(s)', 'Confidence value(s)', 'Expansion method(s)', 'Biological role(s) interactor A', 'Biological role(s) interactor B', 'Experimental role(s) interactor A', 'Experimental role(s) interactor B', 'Type(s) interactor A', 'Type(s) interactor B', 'Xref(s) interactor A', 'Xref(s) interactor B', 'Interaction Xref(s)', 'Annotation(s) interactor A', 'Annotation(s) interactor B', 'Interaction annotation(s)', 'Host organism(s)', 'Interaction parameter(s)', 'Creation date', 'Update date', 'Checksum(s) interactor A', 'Checksum(s) interactor B', 'Interaction Checksum(s)', 'Negative', 'Feature(s) interactor A', 'Feature(s) interactor B', 'Stoichiometry(s) interactor A', 'Stoichiometry(s) interactor B', 'Identification method participant A', 'Identification method participant B']

# %%
#Select data columns to use and create new dataframe

cols = ['#ID(s) interactor A', 'ID(s) interactor B', 'Alias(es) interactor A', 'Alias(es) interactor B', 'Taxid interactor A', 'Taxid interactor B', 'Type(s) interactor A', 'Type(s) interactor B', 'Interaction detection method(s)', 'Publication 1st author(s)', 'Publication Identifier(s)', 'Interaction type(s)', 'Confidence value(s)', 'Biological role(s) interactor A', 'Biological role(s) interactor B', 'Experimental role(s) interactor A', 'Experimental role(s) interactor B', "Expansion method(s)", "Interaction Xref(s)", "Interaction annotation(s)", "Host organism(s)", "Interaction parameter(s)"]
selected_data = original_data[cols].reset_index(drop=True)
selected_data.head(5)
# Out:
#   #ID(s) interactor A ID(s) interactor B  \
# 0    uniprotkb:P31809   uniprotkb:P11224
# 1    uniprotkb:P11224   uniprotkb:P11224
# 2    uniprotkb:P11224   uniprotkb:P11224
# 3    uniprotkb:P11224   uniprotkb:P11224
# 4    uniprotkb:Q0ZME7   uniprotkb:Q0ZME7
#
#                               Alias(es) interactor A  \
# 0  psi-mi:ceam1_mouse(display_long)|uniprotkb:Cea...
# 1  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 2  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 3  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 4  psi-mi:spike_cvhn5(display_long)|uniprotkb:S(g...
#
#                               Alias(es) interactor B  \
# 0  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 1  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 2  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 3  psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 4  psi-mi:spike_cvhn5(display_long)|uniprotkb:S(g...
#
#                                   Taxid interactor A  \
# 0       taxid:10090(mouse)|taxid:10090(Mus musculus)
# 1  taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 2  taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 3  taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 4  taxid:443241(cvhn5)|taxid:443241("Human corona...
#
#                                   Taxid interactor B  \
# 0  taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 1  taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 2  taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 3  taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 4  taxid:443241(cvhn5)|taxid:443241("Human corona...
#
#         Type(s) interactor A       Type(s) interactor B  \
# 0  psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 1  psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 2  psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 3  psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 4  psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
#
#                Interaction detection method(s)   Publication 1st author(s)  \
# 0  psi-mi:"MI:1247"(microscale thermophoresis)         Walls et al. (2016)
# 1           psi-mi:"MI:0067"(light scattering)         Walls et al. (2016)
# 2          psi-mi:"MI:0071"(molecular sieving)         Walls et al. (2016)
# 3     psi-mi:"MI:0410"(3D electron microscopy)         Walls et al. (2016)
# 4     psi-mi:"MI:0410"(3D electron microscopy)  Kirchdoerfer et al. (2016)
#
#    ...  Confidence value(s)     Biological role(s) interactor A  \
# 0  ...  intact-miscore:0.44  psi-mi:"MI:0499"(unspecified role)
# 1  ...  intact-miscore:0.60  psi-mi:"MI:0499"(unspecified role)
# 2  ...  intact-miscore:0.60  psi-mi:"MI:0499"(unspecified role)
# 3  ...  intact-miscore:0.60  psi-mi:"MI:0499"(unspecified role)
# 4  ...  intact-miscore:0.46  psi-mi:"MI:0499"(unspecified role)
#
#       Biological role(s) interactor B   Experimental role(s) interactor A  \
# 0  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 1  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 2  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 3  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 4  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
#
#     Experimental role(s) interactor B Expansion method(s)  \
# 0  psi-mi:"MI:0499"(unspecified role)                   -
# 1  psi-mi:"MI:0499"(unspecified role)                   -
# 2  psi-mi:"MI:0499"(unspecified role)                   -
# 3  psi-mi:"MI:0499"(unspecified role)                   -
# 4  psi-mi:"MI:0499"(unspecified role)                   -
#
#      Interaction Xref(s)                          Interaction annotation(s)  \
# 0  psi-mi:"MI:0465"(dip)  dataset:Coronavirus - Interactions investigate...
# 1  psi-mi:"MI:0465"(dip)  dataset:Coronavirus - Interactions investigate...
# 2  psi-mi:"MI:0465"(dip)  dataset:Coronavirus - Interactions investigate...
# 3  psi-mi:"MI:0465"(dip)  dataset:Coronavirus - Interactions investigate...
# 4  psi-mi:"MI:0465"(dip)  dataset:Coronavirus - Interactions investigate...
#
#                                     Host organism(s) Interaction parameter(s)
# 0              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 1  taxid:7227(drome)|taxid:7227("Drosophila melan...                        -
# 2  taxid:7227(drome)|taxid:7227("Drosophila melan...                        -
# 3  taxid:7227(drome)|taxid:7227("Drosophila melan...                        -
# 4         taxid:9606(human)|taxid:9606(Homo sapiens)                        -
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Extraction of 'gene name' to use as 'node name' (node label)
#
# The **'Alias(es) interactor A/B'** columns contain a list of aliases for each interactor.
# Among those, there are also official gene symbols, so it makes sense to extract the info and use it as node labels.
#
# However, there are complications:
# 1. Not all nodes have the same number of aliases; this means that the (gene_name) might be the first, second or n-position alias, if one is even present.
# 2. All aliases have prefixes that further complicate extracting the information.
# 3. Last but not least, not all nodes are proteins; some of them are chemicals/small molecules, so a different alias should be extracted for these nodes (the best candidate is the one flagged as (display_short)
#
# Below are 2 options to attempt retrieval of the useful information.

# %% [markdown]
# ### Option A
#
# - Split the string at vertical bars and get the substrings as a list in the same dataframe.
# - Then, iterate through every item in the list and discard all those that don't contain '(gene name)'

# %%
# split string into a list whithin the original df

selected_data['Alias(es) interactor A'] = selected_data['Alias(es) interactor A'].str.split('|', expand = False)
selected_data.head(20)
# Out:
#      #ID(s) interactor A ID(s) interactor B  \
# 0       uniprotkb:P31809   uniprotkb:P11224
# 1       uniprotkb:P11224   uniprotkb:P11224
# 2       uniprotkb:P11224   uniprotkb:P11224
# 3       uniprotkb:P11224   uniprotkb:P11224
# 4       uniprotkb:Q0ZME7   uniprotkb:Q0ZME7
# 5       uniprotkb:Q0ZME7   uniprotkb:Q0ZME7
# 6   chebi:"CHEBI:145416"   uniprotkb:Q696P8
# 7       uniprotkb:Q696P8   uniprotkb:Q696P8
# 8    intact:EBI-20623174   uniprotkb:Q53F19
# 9    intact:EBI-20623174   uniprotkb:O60573
# 10   intact:EBI-20623174   uniprotkb:Q8BZR9
# 11   intact:EBI-20623174   uniprotkb:Q8BMB3
# 12   intact:EBI-20623174   uniprotkb:Q53F19
# 13   chebi:"CHEBI:50210"   uniprotkb:Q53F19
# 14   chebi:"CHEBI:50210"   uniprotkb:Q09161
# 15   chebi:"CHEBI:50210"   uniprotkb:Q53F19
# 16   chebi:"CHEBI:50210"   uniprotkb:Q53F19
# 17   chebi:"CHEBI:50210"   uniprotkb:P52298
# 18   chebi:"CHEBI:50210"   uniprotkb:O60573
# 19   chebi:"CHEBI:50210"   uniprotkb:Q09161
#
#                                Alias(es) interactor A  \
# 0   [psi-mi:ceam1_mouse(display_long), uniprotkb:C...
# 1   [psi-mi:spike_cvma5(display_long), uniprotkb:S...
# 2   [psi-mi:spike_cvma5(display_long), uniprotkb:S...
# 3   [psi-mi:spike_cvma5(display_long), uniprotkb:S...
# 4   [psi-mi:spike_cvhn5(display_long), uniprotkb:S...
# 5   [psi-mi:spike_cvhn5(display_long), uniprotkb:S...
# 6   [psi-mi:"methyl 9-o-acetyl-5-(acetylamino)-3,5...
# 7   [psi-mi:q696p8_cvhoc(display_long), uniprotkb:...
# 8   [psi-mi:cvhsa-oligo(display_short), psi-mi:EBI...
# 9   [psi-mi:cvhsa-oligo(display_short), psi-mi:EBI...
# 10  [psi-mi:cvhsa-oligo(display_short), psi-mi:EBI...
# 11  [psi-mi:cvhsa-oligo(display_short), psi-mi:EBI...
# 12  [psi-mi:cvhsa-oligo(display_short), psi-mi:EBI...
# 13  [psi-mi:7-methyl-gtp(display_short), psi-mi:"C...
# 14  [psi-mi:7-methyl-gtp(display_short), psi-mi:"C...
# 15  [psi-mi:7-methyl-gtp(display_short), psi-mi:"C...
# 16  [psi-mi:7-methyl-gtp(display_short), psi-mi:"C...
# 17  [psi-mi:7-methyl-gtp(display_short), psi-mi:"C...
# 18  [psi-mi:7-methyl-gtp(display_short), psi-mi:"C...
# 19  [psi-mi:7-methyl-gtp(display_short), psi-mi:"C...
#
#                                Alias(es) interactor B  \
# 0   psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 1   psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 2   psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 3   psi-mi:spike_cvma5(display_long)|uniprotkb:S(g...
# 4   psi-mi:spike_cvhn5(display_long)|uniprotkb:S(g...
# 5   psi-mi:spike_cvhn5(display_long)|uniprotkb:S(g...
# 6   psi-mi:q696p8_cvhoc(display_long)|uniprotkb:E2...
# 7   psi-mi:q696p8_cvhoc(display_long)|uniprotkb:E2...
# 8   psi-mi:ncbp3_human(display_long)|uniprotkb:C17...
# 9   psi-mi:if4e2_human(display_long)|uniprotkb:EIF...
# 10  psi-mi:ncbp3_mouse(display_long)|uniprotkb:Ncb...
# 11  psi-mi:if4e2_mouse(display_long)|uniprotkb:Eif...
# 12  psi-mi:ncbp3_human(display_long)|uniprotkb:C17...
# 13  psi-mi:ncbp3_human(display_long)|uniprotkb:C17...
# 14  psi-mi:ncbp1_human(display_long)|uniprotkb:NCB...
# 15  psi-mi:ncbp3_human(display_long)|uniprotkb:C17...
# 16  psi-mi:ncbp3_human(display_long)|uniprotkb:C17...
# 17  psi-mi:ncbp2_human(display_long)|uniprotkb:PIG...
# 18  psi-mi:if4e2_human(display_long)|uniprotkb:EIF...
# 19  psi-mi:ncbp1_human(display_long)|uniprotkb:NCB...
#
#                                    Taxid interactor A  \
# 0        taxid:10090(mouse)|taxid:10090(Mus musculus)
# 1   taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 2   taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 3   taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 4   taxid:443241(cvhn5)|taxid:443241("Human corona...
# 5   taxid:443241(cvhn5)|taxid:443241("Human corona...
# 6                                                   -
# 7   taxid:31631(HCoV-OC43)|taxid:31631(Human coron...
# 8   taxid:694009(sars-cov)|taxid:694009(Human SARS...
# 9   taxid:694009(sars-cov)|taxid:694009(Human SARS...
# 10  taxid:694009(sars-cov)|taxid:694009(Human SARS...
# 11  taxid:694009(sars-cov)|taxid:694009(Human SARS...
# 12  taxid:694009(sars-cov)|taxid:694009(Human SARS...
# 13  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 14  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 15  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 16  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 17  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 18  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
# 19  taxid:-2(chemical synthesis)|taxid:-2("Chemica...
#
#                                    Taxid interactor B  \
# 0   taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 1   taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 2   taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 3   taxid:11142(cvma5)|taxid:11142("Murine coronav...
# 4   taxid:443241(cvhn5)|taxid:443241("Human corona...
# 5   taxid:443241(cvhn5)|taxid:443241("Human corona...
# 6   taxid:31631(HCoV-OC43)|taxid:31631(Human coron...
# 7   taxid:31631(HCoV-OC43)|taxid:31631(Human coron...
# 8          taxid:9606(human)|taxid:9606(Homo sapiens)
# 9          taxid:9606(human)|taxid:9606(Homo sapiens)
# 10       taxid:10090(mouse)|taxid:10090(Mus musculus)
# 11       taxid:10090(mouse)|taxid:10090(Mus musculus)
# 12         taxid:9606(human)|taxid:9606(Homo sapiens)
# 13         taxid:9606(human)|taxid:9606(Homo sapiens)
# 14         taxid:9606(human)|taxid:9606(Homo sapiens)
# 15         taxid:9606(human)|taxid:9606(Homo sapiens)
# 16         taxid:9606(human)|taxid:9606(Homo sapiens)
# 17         taxid:9606(human)|taxid:9606(Homo sapiens)
# 18         taxid:9606(human)|taxid:9606(Homo sapiens)
# 19         taxid:9606(human)|taxid:9606(Homo sapiens)
#
#                   Type(s) interactor A       Type(s) interactor B  \
# 0            psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 1            psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 2            psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 3            psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 4            psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 5            psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 6     psi-mi:"MI:0328"(small molecule)  psi-mi:"MI:0326"(protein)
# 7            psi-mi:"MI:0326"(protein)  psi-mi:"MI:0326"(protein)
# 8   psi-mi:"MI:0320"(ribonucleic acid)  psi-mi:"MI:0326"(protein)
# 9   psi-mi:"MI:0320"(ribonucleic acid)  psi-mi:"MI:0326"(protein)
# 10  psi-mi:"MI:0320"(ribonucleic acid)  psi-mi:"MI:0326"(protein)
# 11  psi-mi:"MI:0320"(ribonucleic acid)  psi-mi:"MI:0326"(protein)
# 12  psi-mi:"MI:0320"(ribonucleic acid)  psi-mi:"MI:0326"(protein)
# 13    psi-mi:"MI:0328"(small molecule)  psi-mi:"MI:0326"(protein)
# 14    psi-mi:"MI:0328"(small molecule)  psi-mi:"MI:0326"(protein)
# 15    psi-mi:"MI:0328"(small molecule)  psi-mi:"MI:0326"(protein)
# 16    psi-mi:"MI:0328"(small molecule)  psi-mi:"MI:0326"(protein)
# 17    psi-mi:"MI:0328"(small molecule)  psi-mi:"MI:0326"(protein)
# 18    psi-mi:"MI:0328"(small molecule)  psi-mi:"MI:0326"(protein)
# 19    psi-mi:"MI:0328"(small molecule)  psi-mi:"MI:0326"(protein)
#
#                       Interaction detection method(s)  \
# 0         psi-mi:"MI:1247"(microscale thermophoresis)
# 1                  psi-mi:"MI:0067"(light scattering)
# 2                 psi-mi:"MI:0071"(molecular sieving)
# 3            psi-mi:"MI:0410"(3D electron microscopy)
# 4            psi-mi:"MI:0410"(3D electron microscopy)
# 5   psi-mi:"MI:0020"(transmission electron microsc...
# 6            psi-mi:"MI:0410"(3D electron microscopy)
# 7            psi-mi:"MI:0410"(3D electron microscopy)
# 8                         psi-mi:"MI:0096"(pull down)
# 9                         psi-mi:"MI:0096"(pull down)
# 10                        psi-mi:"MI:0096"(pull down)
# 11                        psi-mi:"MI:0096"(pull down)
# 12                        psi-mi:"MI:0096"(pull down)
# 13                        psi-mi:"MI:0096"(pull down)
# 14                        psi-mi:"MI:0096"(pull down)
# 15                        psi-mi:"MI:0096"(pull down)
# 16                        psi-mi:"MI:0096"(pull down)
# 17                        psi-mi:"MI:0096"(pull down)
# 18                        psi-mi:"MI:0096"(pull down)
# 19                        psi-mi:"MI:0096"(pull down)
#
#      Publication 1st author(s)  ...  Confidence value(s)  \
# 0          Walls et al. (2016)  ...  intact-miscore:0.44
# 1          Walls et al. (2016)  ...  intact-miscore:0.60
# 2          Walls et al. (2016)  ...  intact-miscore:0.60
# 3          Walls et al. (2016)  ...  intact-miscore:0.60
# 4   Kirchdoerfer et al. (2016)  ...  intact-miscore:0.46
# 5   Kirchdoerfer et al. (2016)  ...  intact-miscore:0.46
# 6      Tortorici et al. (2019)  ...  intact-miscore:0.36
# 7      Tortorici et al. (2019)  ...  intact-miscore:0.36
# 8       Gebhardt et al. (2015)  ...  intact-miscore:0.59
# 9       Gebhardt et al. (2015)  ...  intact-miscore:0.35
# 10      Gebhardt et al. (2015)  ...  intact-miscore:0.35
# 11      Gebhardt et al. (2015)  ...  intact-miscore:0.35
# 12      Gebhardt et al. (2015)  ...  intact-miscore:0.59
# 13      Gebhardt et al. (2015)  ...  intact-miscore:0.59
# 14      Gebhardt et al. (2015)  ...  intact-miscore:0.69
# 15      Gebhardt et al. (2015)  ...  intact-miscore:0.59
# 16      Gebhardt et al. (2015)  ...  intact-miscore:0.59
# 17      Gebhardt et al. (2015)  ...  intact-miscore:0.69
# 18      Gebhardt et al. (2015)  ...  intact-miscore:0.35
# 19      Gebhardt et al. (2015)  ...  intact-miscore:0.69
#
#        Biological role(s) interactor A     Biological role(s) interactor B  \
# 0   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 1   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 2   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 3   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 4   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 5   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 6   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 7   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 8   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 9   psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 10  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 11  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 12  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 13  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 14  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 15  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 16  psi-mi:"MI:0499"(unspecified role)         psi-mi:"MI:0684"(ancillary)
# 17  psi-mi:"MI:0499"(unspecified role)         psi-mi:"MI:0684"(ancillary)
# 18  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
# 19  psi-mi:"MI:0499"(unspecified role)  psi-mi:"MI:0499"(unspecified role)
#
#       Experimental role(s) interactor A    Experimental role(s) interactor B  \
# 0    psi-mi:"MI:0499"(unspecified role)   psi-mi:"MI:0499"(unspecified role)
# 1    psi-mi:"MI:0499"(unspecified role)   psi-mi:"MI:0499"(unspecified role)
# 2    psi-mi:"MI:0499"(unspecified role)   psi-mi:"MI:0499"(unspecified role)
# 3    psi-mi:"MI:0499"(unspecified role)   psi-mi:"MI:0499"(unspecified role)
# 4    psi-mi:"MI:0499"(unspecified role)   psi-mi:"MI:0499"(unspecified role)
# 5    psi-mi:"MI:0499"(unspecified role)   psi-mi:"MI:0499"(unspecified role)
# 6   psi-mi:"MI:0497"(neutral component)  psi-mi:"MI:0497"(neutral component)
# 7   psi-mi:"MI:0497"(neutral component)  psi-mi:"MI:0497"(neutral component)
# 8                psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 9                psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 10               psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 11               psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 12               psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 13               psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 14               psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 15               psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 16               psi-mi:"MI:0496"(bait)  psi-mi:"MI:0497"(neutral component)
# 17               psi-mi:"MI:0496"(bait)  psi-mi:"MI:0497"(neutral component)
# 18               psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
# 19               psi-mi:"MI:0496"(bait)               psi-mi:"MI:0498"(prey)
#
#                   Expansion method(s)       Interaction Xref(s)  \
# 0                                   -     psi-mi:"MI:0465"(dip)
# 1                                   -     psi-mi:"MI:0465"(dip)
# 2                                   -     psi-mi:"MI:0465"(dip)
# 3                                   -     psi-mi:"MI:0465"(dip)
# 4                                   -     psi-mi:"MI:0465"(dip)
# 5                                   -     psi-mi:"MI:0465"(dip)
# 6                                   -   emdb:EMD-0557(see-also)
# 7                                   -  emdb:EMD-20070(see-also)
# 8   psi-mi:"MI:1060"(spoke expansion)                         -
# 9   psi-mi:"MI:1060"(spoke expansion)                         -
# 10  psi-mi:"MI:1060"(spoke expansion)                         -
# 11  psi-mi:"MI:1060"(spoke expansion)                         -
# 12                                  -                         -
# 13  psi-mi:"MI:1060"(spoke expansion)                         -
# 14  psi-mi:"MI:1060"(spoke expansion)                         -
# 15                                  -                         -
# 16  psi-mi:"MI:1060"(spoke expansion)                         -
# 17  psi-mi:"MI:1060"(spoke expansion)                         -
# 18  psi-mi:"MI:1060"(spoke expansion)                         -
# 19  psi-mi:"MI:1060"(spoke expansion)                         -
#
#                             Interaction annotation(s)  \
# 0   dataset:Coronavirus - Interactions investigate...
# 1   dataset:Coronavirus - Interactions investigate...
# 2   dataset:Coronavirus - Interactions investigate...
# 3   dataset:Coronavirus - Interactions investigate...
# 4   dataset:Coronavirus - Interactions investigate...
# 5   dataset:Coronavirus - Interactions investigate...
# 6   figure legend:Fig. 1, Table 1, Supplementary F...
# 7   figure legend:Fig. 1, Table 1, Supplementary F...
# 8   figure legend:Fig. 2D|comment:a similar intera...
# 9   figure legend:Fig. 2D|comment:a similar intera...
# 10  figure legend:Fig. 2D|dataset:Coronavirus - In...
# 11  figure legend:Fig. 2D|dataset:Coronavirus - In...
# 12  figure legend:Fig. 3D, 3H|comment:"\"To study ...
# 13  figure legend:Fig. 2E|dataset:Coronavirus - In...
# 14  figure legend:Fig. 2E|dataset:Coronavirus - In...
# 15  figure legend:Fig. 3E|dataset:Coronavirus - In...
# 16  figure legend:Fig. 4E|comment:"\"Consistent wi...
# 17  figure legend:Fig. 4E|comment:"\"Consistent wi...
# 18  figure legend:Fig. 4E|comment:"\"Consistent wi...
# 19  figure legend:Fig. 4E|comment:"\"Consistent wi...
#
#                                      Host organism(s) Interaction parameter(s)
# 0               taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 1   taxid:7227(drome)|taxid:7227("Drosophila melan...                        -
# 2   taxid:7227(drome)|taxid:7227("Drosophila melan...                        -
# 3   taxid:7227(drome)|taxid:7227("Drosophila melan...                        -
# 4          taxid:9606(human)|taxid:9606(Homo sapiens)                        -
# 5          taxid:9606(human)|taxid:9606(Homo sapiens)                        -
# 6   taxid:9606(human-293f)|taxid:9606(Homo sapiens...                        -
# 7   taxid:9606(human-293f)|taxid:9606(Homo sapiens...                        -
# 8               taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 9               taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 10              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 11              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 12              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 13              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 14              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 15              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 16              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 17              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 18              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
# 19              taxid:-1(in vitro)|taxid:-1(In vitro)                        -
#
# [20 rows x 22 columns]

# %%
# create a list of values for a specific dataframe column, then iterate through the
#values (that are temselves lists) and remove all that do not match the desired condition

aliases_list = selected_data['Alias(es) interactor A'].to_list()
print(aliases_list)
# Out:
# [['psi-mi:ceam1_mouse(display_long)', 'uniprotkb:Ceacam1(gene name)', 'psi-mi:Ceacam1(display_short)', 'uniprotkb:Bgp(gene name synonym)', 'uniprotkb:Bgp1(gene name synonym)', 'uniprotkb:Biliary glycoprotein 1(gene name synonym)', 'uniprotkb:Murine hepatitis virus receptor(gene name synonym)', 'uniprotkb:MHVR1(gene name synonym)', 'uniprotkb:Biliary glycoprotein D(gene name synonym)'], ['psi-mi:spike_cvma5(display_long)', 'uniprotkb:S(gene name)', 'psi-mi:S(display_short)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:Peplomer protein(gene name synonym)', 'uniprotkb:3(orf name)'], ['psi-mi:spike_cvma5(display_long)', 'uniprotkb:S(gene name)', 'psi-mi:S(display_short)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:Peplomer protein(gene name synonym)', 'uniprotkb:3(orf name)'], ['psi-mi:spike_cvma5(display_long)', 'uniprotkb:S(gene name)', 'psi-mi:S(display_short)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:Peplomer protein(gene name synonym)', 'uniprotkb:3(orf name)'], ['psi-mi:spike_cvhn5(display_long)', 'uniprotkb:S(gene name)', 'psi-mi:S(display_short)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:Peplomer protein(gene name synonym)', 'uniprotkb:3(orf name)'], ['psi-mi:spike_cvhn5(display_long)', 'uniprotkb:S(gene name)', 'psi-mi:S(display_short)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:Peplomer protein(gene name synonym)', 'uniprotkb:3(orf name)'], ['psi-mi:"methyl 9-o-acetyl-5-(acetylamino)-3,5-dideoxy-d-glycero-alpha-d-galacto-non-2-ulopyranosidonic acid"(display_short)', 'psi-mi:"CHEBI:145416"(display_long)'], ['psi-mi:q696p8_cvhoc(display_long)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:Peplomer protein(gene name synonym)', 'uniprotkb:S(gene name)', 'psi-mi:S(display_short)'], ['psi-mi:cvhsa-oligo(display_short)', 'psi-mi:EBI-20623174(display_long)'], ['psi-mi:cvhsa-oligo(display_short)', 'psi-mi:EBI-20623174(display_long)'], ['psi-mi:cvhsa-oligo(display_short)', 'psi-mi:EBI-20623174(display_long)'], ['psi-mi:cvhsa-oligo(display_short)', 'psi-mi:EBI-20623174(display_long)'], ['psi-mi:cvhsa-oligo(display_short)', 'psi-mi:EBI-20623174(display_long)'], ['psi-mi:7-methyl-gtp(display_short)', 'psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:7-methyl-gtp(display_short)', 'psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:7-methyl-gtp(display_short)', 'psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:7-methyl-gtp(display_short)', 'psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:7-methyl-gtp(display_short)', 'psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:7-methyl-gtp(display_short)', 'psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:7-methyl-gtp(display_short)', 'psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:ncbp3_human(display_long)', 'uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:Protein ELG(gene name synonym)', 'uniprotkb:NCBP3(gene name)', 'psi-mi:NCBP3(display_short)'], ['psi-mi:ncbp3_human(display_long)', 'uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:Protein ELG(gene name synonym)', 'uniprotkb:NCBP3(gene name)', 'psi-mi:NCBP3(display_short)'], ['psi-mi:ncbp3_human(display_long)', 'uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:Protein ELG(gene name synonym)', 'uniprotkb:NCBP3(gene name)', 'psi-mi:NCBP3(display_short)'], ['psi-mi:ncbp3_human(display_long)', 'uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:Protein ELG(gene name synonym)', 'uniprotkb:NCBP3(gene name)', 'psi-mi:NCBP3(display_short)'], ['psi-mi:ncbp3_human(display_long)', 'uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:Protein ELG(gene name synonym)', 'uniprotkb:NCBP3(gene name)', 'psi-mi:NCBP3(display_short)'], ['psi-mi:ncbp3_human(display_long)', 'uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:Protein ELG(gene name synonym)', 'uniprotkb:NCBP3(gene name)', 'psi-mi:NCBP3(display_short)'], ['psi-mi:ncbp3_human(display_long)', 'uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:Protein ELG(gene name synonym)', 'uniprotkb:NCBP3(gene name)', 'psi-mi:NCBP3(display_short)'], ['psi-mi:ncbp3_human(display_long)', 'uniprotkb:C17or ...

# %%
# iterate through the list of items and each item's elements and remove
# all elements that don't match the specified condition; in this case, if the element(string)
# doesn't contain the substrings 'gene display', it will be deleted. I expect this to preserve all
# the strings that are (gene name), (gene name synonym), (display_long) and (display_short).

for item in aliases_list:
    for element in item:
        if not 'gene display' in element:
            item.remove(element)
            
print(aliases_list)
# Out:
# [['uniprotkb:Ceacam1(gene name)', 'uniprotkb:Bgp(gene name synonym)', 'uniprotkb:Biliary glycoprotein 1(gene name synonym)', 'uniprotkb:MHVR1(gene name synonym)'], ['uniprotkb:S(gene name)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:3(orf name)'], ['uniprotkb:S(gene name)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:3(orf name)'], ['uniprotkb:S(gene name)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:3(orf name)'], ['uniprotkb:S(gene name)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:3(orf name)'], ['uniprotkb:S(gene name)', 'uniprotkb:E2(gene name synonym)', 'uniprotkb:3(orf name)'], ['psi-mi:"CHEBI:145416"(display_long)'], ['uniprotkb:E2(gene name synonym)', 'uniprotkb:S(gene name)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', 'uniprotkb:NCBP3(gene name)'], ['uniprotkb:C17orf85(gene name synonym)', ' ...

# %%
# the list is now contaminated with gene name synonyms, that must be removed. 
# Also, some entries will have (display_short). Those should be eliminated too.
# (display_long) is what I want to keep because some values only have these.
#I can use the same loop again

for item in aliases_list:
    for element in item:
        if 'synonym' in element or 'short' in element:
            item.remove(element)
            
print(aliases_list)
# Out:
# [['uniprotkb:Ceacam1(gene name)', 'uniprotkb:Biliary glycoprotein 1(gene name synonym)'], ['uniprotkb:S(gene name)', 'uniprotkb:3(orf name)'], ['uniprotkb:S(gene name)', 'uniprotkb:3(orf name)'], ['uniprotkb:S(gene name)', 'uniprotkb:3(orf name)'], ['uniprotkb:S(gene name)', 'uniprotkb:3(orf name)'], ['uniprotkb:S(gene name)', 'uniprotkb:3(orf name)'], ['psi-mi:"CHEBI:145416"(display_long)'], ['uniprotkb:S(gene name)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:EBI-20623174(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['psi-mi:"CHEBI:50210"(display_long)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:NCBP3(gene name)'], ['uniprotkb:PIG55(orf name)', 'uniprotkb:Cell proliferation-inducing gene 55 protein(gene name synonym)'], ['uniprotkb:PIG55(orf name)', 'uniprotkb:Cell proliferation-inducing gene 55 protein(gene name synonym)'], ['uniprotkb:PIG55(orf name)', 'uniprotkb:Cell proliferation-inducing ge ...

# %%
#Create new dataframe with cleaned up aliases

cleaned_aliases = pd.DataFrame(aliases_list)
cleaned_aliases.head(700)
# Out:
#                                 0  \
# 0    uniprotkb:Ceacam1(gene name)
# 1          uniprotkb:S(gene name)
# 2          uniprotkb:S(gene name)
# 3          uniprotkb:S(gene name)
# 4          uniprotkb:S(gene name)
# ..                            ...
# 695                          None
# 696                          None
# 697                          None
# 698                          None
# 699                          None
#
#                                                      1     2
# 0    uniprotkb:Biliary glycoprotein 1(gene name syn...  None
# 1                                uniprotkb:3(orf name)  None
# 2                                uniprotkb:3(orf name)  None
# 3                                uniprotkb:3(orf name)  None
# 4                                uniprotkb:3(orf name)  None
# ..                                                 ...   ...
# 695                                               None  None
# 696                                               None  None
# 697                                               None  None
# 698                                               None  None
# 699                                               None  None
#
# [700 rows x 3 columns]

# %%
# Column '0' looks good BUT some cells end up having None values and I don't understand
# why that happens....

#In addition, in column 1, I see values that include (orf name):
# those should have been eliminated earlier during the first FOR LOOP...
# Am I missing something?

# I also need to remove prefixes as well as the text in parenthesis

# %%
cleaned_aliases[0] = cleaned_aliases[0].str.replace("uniprotkb:", "", regex=False)
cleaned_aliases[0] = cleaned_aliases[0].str.replace("psi-mi:", "", regex=False)
cleaned_aliases[0] = cleaned_aliases[0].str.replace("(gene name)", "", regex=False)
cleaned_aliases[0] = cleaned_aliases[0].str.replace("(display_long)", "", regex=False)
cleaned_aliases[0] = cleaned_aliases[0].str.replace("(display_short", "", regex=False)

cleaned_aliases[0] = cleaned_aliases[0].str.strip('"')

cleaned_aliases.head(700)

# %% [markdown]
# ### Option B
#
# Alternatively, setting 'expand=True' will expand the substring in a new dataframe.
#
# Most of the gene names are in column 1, so option B is pretty good, but some nodes will not have human readable names because of the reasons explaind above.

# %%
expanded_aliases = selected_data['Alias(es) interactor A'].str.split('|', expand = True)
expanded_aliases.head(5)

# %%
# Most of the gene names are in column 1, so option B is pretty good,
# but some nodes will not have human readable names.

# Option A might be better because we can manipulate the list of values... But I can t figure out how to do that.

# %%
# Option A

# %%
********************

# %%
df3[1] = df3[1].str.replace("(gene name)", "", regex=False)
df3[1] = df3[1].str.replace("(gene name synonym)", "", regex=False)
df3[1] = df3[1].str.replace("(display_long)", "", regex=False)
df3.head()

# %%
df2['name A'] = df3[1]
df2.head()

# %%
# SAME PROCEDURE NEEDS TO BE DONE FOR "ALIAS (ES) INTERACTOR B" column

# %%
# Correct header name and drop duplicate columns
df2['ID(s) interactor A'] = df2['#ID(s) interactor A']
df2.drop(columns =["Alias(es) interactor A", "Alias(es) interactor B", '#ID(s) interactor A'], inplace = True)
df2.head(3)

# %%
#Get columns headers as list
new_cols = df2.columns.values.tolist()
print(new_cols)

# Re-order columns in final dataframe
df2 = df2[['ID(s) interactor A', 'ID(s) interactor B', 'name A', 'name B', 'Interaction detection method(s)', 'Publication 1st author(s)', 'Publication Identifier(s)', 'Taxid interactor A', 'Taxid interactor B', 'Interaction type(s)', 'Confidence value(s)', 'Biological role(s) interactor A', 'Biological role(s) interactor B', 'Experimental role(s) interactor A', 'Experimental role(s) interactor B']]
df2.head(3)
