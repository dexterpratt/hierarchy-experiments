# %% [markdown]
# ### Imports

# %%
from ndex2.nice_cx_network import NiceCXNetwork
import ndex2.client as nc
import ndex2
print("ndex2 version: " + ndex2.__version__)
import networkx as nx
print("networkx version: " + nx.__version__)
import pandas as pd
print("pandas version: " + pd.__version__)
import os
import sys
# Out:
# ndex2 version: 3.3.1
# networkx version: 2.4
# pandas version: 1.0.3

# %%
 def nice_cx_to_node_dataframe(nice_cx_network):
    """
    Create a Pandas DataFrame in which each row is a node and columns are node attributes.
     Example:
        ``df = nice_cx_to_node_dataframe(my_nice_cx_network) # df is now a pandas dataframe``
    :return: Pandas dataframe
    :rtype: Pandas dataframe
    """
    #TODO expand documentation
    rows = []
    node_items = None
    if sys.version_info.major == 3:
        node_items = nice_cx_network.nodes.items()
    else:
        node_items = nice_cx_network.nodes.iteritems()
    # v is the node item values
    # k is the index of the node
    attribute_names = {"name", "node_id"}
    for node_id, v in node_items:
        row = {}
        row["name"] = v.get('n')
        row["node_id"] = node_id
        for attribute in nice_cx_network.get_node_attributes(node_id):
            attribute_names.add(attribute.get('n'))
            row[attribute.get('n')] = attribute.get('v')
        rows.append(row)
    df_columns = list(attribute_names)
    return_df = pd.DataFrame(rows, columns=df_columns)
    return return_df

def jaccard_similarity_lists(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(list1) + len(list2)) - intersection
    return float(intersection) / union

def jaccard_similarity_sets(set1, set2):
    intersection = len(list(set1.intersection(set2)))
    union = (len(set1) + len(set2)) - intersection
    return float(intersection) / union

# %% [markdown]
# ### The NDEx Account

# %%
my_account="dexterpratt"
my_password="cytoscaperules"
my_server="http://public.ndexbio.org"

if my_account == 'enter your username here':
    print('*******WARNING!!!!*******')
    print('Please change the username and password before proceeding')
else:
    try:
        my_ndex=nc.Ndex2(my_server, my_account, my_password)
        my_ndex.update_status()
        print("Success.  Please continue.")
    except Exception as inst:
        print("Could not access account %s with password %s" % (my_account, my_password))
        print(inst.args)
# Out:
# Success.  Please continue.

# %% [markdown]
# ### The COVID-19 - Human Interactors Gene Set and Network

# %%
interactor_set = {"F2RL1", "ADAM9", "TOR1A", "PMPCA", "CISD3", "ATP13A3", "MPHOSPH10", "SLC27A2", "TIMM10B", "GORASP1", "GNG5", "EXOSC5", "EMC1", "NPC2", "PPT1", "AGPS", "LMAN2", "CDK5RAP2", "PLD3", "NUP98", "PLOD2", "NPTX1", "GCC1", "RBM28", "LARP1", "REEP5", "MDN1", "TBK1", "TM2D3", "CLCC1", "FAM8A1", "PTBP2", "POR", "RAB5C", "GTF2F2", "GRIPAP1", "VPS39", "NEU1", "MOGS", "GOLGB1", "PLAT", "AKAP9", "PTGES2", "DPY19L1", "SLC30A9", "PDE4DIP", "HS6ST2", "RNF41", "FBN2", "G3BP2", "NDFIP2", "VPS11", "BRD4", "C1orf50", "NUP210", "PIGO", "IMPDH2", "GPAA1", "GDF15", "PIGS", "ERO1B", "ZNF318", "WASHC4", "AP2A2", "ARL6IP6", "NGLY1", "ACSL3", "TOMM70", "EDEM3", "LOX", "PDZD11", "RAB18", "NARS2", "NUP88", "TARS2", "FKBP15", "INTS4", "AP3B1", "ERGIC1", "NINL", "
interaction_network_uuid = "5d97a04a-6fab-11ea-bfdc-0ac135e8bacf" 
interaction_network = ndex2.create_nice_cx_from_server(server='public.ndexbio.org', uuid=interaction_network_uuid, 
                                                    password=my_password, username=my_account)

# %% [markdown]
# ### The Hierarchy + Interactors

# %%
hierarchy_uuid = "6a0eb117-7a19-11ea-aaef-0ac135e8bacf" # interconnect with viral proteins
#hierarchy_uuid = "24d586f5-7833-11ea-aaef-0ac135e8bacf" # interconnect with viral proteins
#hierarchy_uuid = "3f3f10a8-75d6-11ea-aaef-0ac135e8bacf" # diffusion
# hierarchy_uuid = "b7c7d89e-75d6-11ea-aaef-0ac135e8bacf" # neighborhood
# hierarchy_uuid = "8639b05b-75d6-11ea-aaef-0ac135e8bacf" #interconnect
hierarchy_network = ndex2.create_nice_cx_from_server(server='public.ndexbio.org', uuid=hierarchy_uuid, 
                                                    password=my_password, username=my_account)
# append "interactors" to its name to indicate that interactor annotations have been addded
#hierarchy_network.set_name(hierarchy_network.get_name() + " - interactors")
# add the interactors as a network attribute
#hierarchy_network.set_network_attribute("COVID-19-interactors", list(interactor_set), type="list_of_string")

# %%
hierarchy_network.edges
# Out:
# {55275: {'@id': 55275, 's': 54589, 't': 54590, 'i': 'interacts with'},
#  55274: {'@id': 55274, 's': 54589, 't': 54591, 'i': 'interacts with'},
#  55273: {'@id': 55273, 's': 54589, 't': 54233, 'i': 'interacts with'},
#  55272: {'@id': 55272, 's': 54589, 't': 54234, 'i': 'interacts with'},
#  55271: {'@id': 55271, 's': 54589, 't': 54235, 'i': 'interacts with'},
#  55270: {'@id': 55270, 's': 54589, 't': 54236, 'i': 'interacts with'},
#  55269: {'@id': 55269, 's': 54589, 't': 54237, 'i': 'interacts with'},
#  55268: {'@id': 55268, 's': 54589, 't': 54238, 'i': 'interacts with'},
#  55267: {'@id': 55267, 's': 54589, 't': 54239, 'i': 'interacts with'},
#  55266: {'@id': 55266, 's': 54589, 't': 54240, 'i': 'interacts with'},
#  55265: {'@id': 55265, 's': 54589, 't': 54241, 'i': 'interacts with'},
#  55264: {'@id': 55264, 's': 54589, 't': 54242, 'i': 'interacts with'},
#  55263: {'@id': 55263, 's': 54589, 't': 54243, 'i': 'interacts with'},
#  55262: {'@id': 55262, 's': 54589, 't': 54244, 'i': 'interacts with'},
#  55261: {'@id': 55261, 's': 54589, 't': 54245, 'i': 'interacts with'},
#  55260: {'@id': 55260, 's': 54589, 't': 54246, 'i': 'interacts with'},
#  55259: {'@id': 55259, 's': 54589, 't': 54247, 'i': 'interacts with'},
#  55258: {'@id': 55258, 's': 54589, 't': 54248, 'i': 'interacts with'},
#  55257: {'@id': 55257, 's': 54589, 't': 54249, 'i': 'interacts with'},
#  55256: {'@id': 55256, 's': 54589, 't': 54250, 'i': 'interacts with'},
#  55255: {'@id': 55255, 's': 54587, 't': 54588, 'i': 'interacts with'},
#  55254: {'@id': 55254, 's': 54582, 't': 54585, 'i': 'interacts with'},
#  55253: {'@id': 55253, 's': 54581, 't': 54582, 'i': 'interacts with'},
#  55252: {'@id': 55252, 's': 54581, 't': 54583, 'i': 'interacts with'},
#  55251: {'@id': 55251, 's': 54581, 't': 54584, 'i': 'interacts with'},
#  55250: {'@id': 55250, 's': 54581, 't': 54585, 'i': 'interacts with'},
#  55249: {'@id': 55249, 's': 54581, 't': 54586, 'i': 'interacts with'},
#  55248: {'@id': 55248, 's': 54578, 't': 54576, 'i': 'interacts with'},
#  55247: {'@id': 55247, 's': 54578, 't': 54577, 'i': 'interacts with'},
#  55246: {'@id': 55246, 's': 54576, 't': 54577, 'i': 'interacts with'},
#  55245: {'@id': 55245, 's': 54575, 't': 54578, 'i': 'interacts with'},
#  55244: {'@id': 55244, 's': 54575, 't': 54576, 'i': 'interacts with'},
#  55243: {'@id': 55243, 's': 54575, 't': 54577, 'i': 'interacts with'},
#  55242: {'@id': 55242, 's': 54574, 't': 54575, 'i': 'interacts with'},
#  55241: {'@id': 55241, 's': 54574, 't': 54576, 'i': 'interacts with'},
#  55240: {'@id': 55240, 's': 54574, 't': 54577, 'i': 'interacts with'},
#  55239: {'@id': 55239, 's': 54574, 't': 54578, 'i': 'interacts with'},
#  55238: {'@id': 55238, 's': 54574, 't': 54579, 'i': 'interacts with'},
#  55237: {'@id': 55237, 's': 54574, 't': 54580, 'i': 'interacts with'},
#  55236: {'@id': 55236, 's': 54573, 't': 54572, 'i': 'interacts with'},
#  55235: {'@id': 55235, 's': 54571, 't': 54572, 'i': 'interacts with'},
#  55234: {'@id': 55234, 's': 54571, 't': 54573, 'i': 'interacts with'},
#  55233: {'@id': 55233, 's': 54569, 't': 54570, 'i': 'interacts with'},
#  55232: {'@id': 55232, 's': 54568, 't': 54569, 'i': 'interacts with'},
#  55231: {'@id': 55231, 's': 54568, 't': 54570, 'i': 'interacts with'},
#  55230: {'@id': 55230, 's': 54566, 't': 54557, 'i': 'interacts with'},
#  55229: {'@id': 55229, 's': 54566, 't': 54570, 'i': 'interacts with'},
#  55228: {'@id': 55228, 's': 54562, 't': 54557, 'i': 'interacts with'},
#  55227: {'@id': 55227, 's': 54555, 't': 54564, 'i': 'interacts with'},
#  55226: {'@id': 55226, 's': 54555, 't': 54565, 'i': 'interacts with'},
#  55225: {'@id': 55225, 's': 54555, 't': 54566, 'i': 'interacts with'},
#  55224: {'@id': 55224, 's': 54555, 't': 54567, 'i': 'interacts with'},
#  55223: {'@id': 55223, 's': 54555, 't': 54568, 'i': 'interacts with'},
#  55222: {'@id': 55222, 's': 54555, 't': 54569, 'i': 'interacts with'},
#  55221: {'@id': 55221, 's': 54555, 't': 54570, 'i': 'interacts with'},
#  55220: {'@id': 55220, 's': 54555, 't': 54556, 'i': 'interacts with'},
#  55219: {'@id': 55219, 's': 54555, 't': 54557, 'i': 'interacts with'},
#  55218: {'@id': 55218, 's': 54555, 't': 54558, 'i': 'interacts with'},
#  55217: {'@id': 55217, 's': 54555, 't': 54559, 'i': 'interacts with'},
#  55216: {'@id': 55216, 's': 54555, 't': 54560, 'i': 'interacts with'},
#  55215: {'@id': 55215, 's': 54555, 't': 54561, 'i': 'interacts with'},
#  55214: {'@id': 55214, 's': 54555, 't': 54562, 'i': 'interacts with'},
#  55213: {'@id': 55213, 's': 54555, 't': 54563, 'i': 'interacts with'},
#  55212: {'@id': 55212, 's': 54547, 't': 54541, 'i': 'interacts with'},
#  55211: {'@id': 55211, 's': 54524, 't': 54525, 'i': 'interacts with'},
#  55210: {'@id': 55210, 's': 54524, 't': 54526, 'i': 'interacts with'},
#  55209: {'@id': 55209, 's': 54524, 't': 54527, 'i': 'interacts with'},
#  55208: {'@id': 55208, 's': 54524, 't': 54528, 'i': 'interacts with'},
#  55207: {'@id': 55207, 's': 54524, 't': 54529, 'i': 'interacts with'},
#  55206: {'@id': 55206, 's': 54524, 't': 54530, 'i': 'interacts with'},
#  55205: {'@id': 55205, 's': 54524, 't': 54531, 'i': 'interacts with'},
#  55204: {'@id': 55204, 's': 54524, 't': 54532, 'i': 'interacts with'},
#  55203: {'@id': 55203, 's': 54524, 't': 54533, 'i': 'interacts with'},
#  55202: {'@id': 55202, 's': 54524, 't': 54534, 'i': 'interacts with'},
#  55201: {'@id': 55201, 's': 54524, 't': 54535, 'i': 'interacts with'},
#  55200: {'@id': 55200, 's': 54524, 't': 54536, 'i': 'interacts with'},
#  55199: {'@id': 55199, 's': 54524, 't': 54537, 'i': 'interacts with'},
#  55198: {'@id': 55198, 's': 54524, 't': 54538, 'i': 'interacts with'},
#  55197: {'@id': 55197, 's': 54524, 't': 54539, 'i': 'interacts with'},
#  55196: {'@id': 55196, 's': 54524, 't': 54540, 'i': 'interacts with'},
#  55195: {'@id': 55195, 's': 54524, 't': 54541, 'i': 'interacts with'},
#  55194: {'@id': 55194, 's': 54524, 't': 54542, 'i': 'interacts with'},
#  55193: {'@id': 55193, 's': 54524, 't': 54543, 'i': 'interacts with'},
#  55192: {'@id': 55192, 's': 54524, 't': 54544, 'i': 'interacts with'},
#  55191: {'@id': 55191, 's': 54524, 't': 54545, 'i': 'interacts with'},
#  55190: {'@id': 55190, 's': 54524, 't': 54546, 'i': 'interacts with'},
#  55189: {'@id': 55189, 's': 54524, 't': 54547, 'i': 'interacts with'},
#  55188: {'@id': 55188, 's': 54524, 't': 54548, 'i': 'interacts with'},
#  55187: {'@id': 55187, 's': 54524, 't': 54549, 'i': 'interacts with'},
#  55186: {'@id': 55186, 's': 54524, 't': 54550, 'i': 'interacts with'},
#  55185: {'@id': 55185, 's': 54524, 't': 54551, 'i': 'interacts with'},
#  55184: {'@id': 55184, 's': 54524, 't': 54552, 'i': 'interacts with'},
#  55183: {'@id': 55183, 's': 54524, 't': 54553, 'i': 'interacts with'},
#  55182: {'@id': 55182, 's': 54524, 't': 54554, 'i': 'interacts with'},
#  55181: {'@id': 55181, 's': 54517, 't': 54518, 'i': 'interacts with'},
#  55180: {'@id': 55180, 's': 54517, 't': 54519, 'i': 'interacts with'},
#  55179: {'@id': 55179, 's': 54517, 't': 54520, 'i': 'interacts with'},
#  55178: {'@id': 55178, 's': 54517, 't': 54521, 'i': 'interacts with'},
#  55177: {'@id': 55177, 's': 54517, 't': 54522, 'i': 'interacts with'},
#  55176: {'@id': 55176, 's': 54517, 't': 54523, 'i': 'interacts with'},
#  55175: {'@id': 55175, 's': 54505, 't': 54512, 'i': 'interacts with'},
#  55174: {'@id': 55174, 's': 54491, 't': 54515, 'i': 'interacts with'},
#  55173: {'@id': 55173, 's': 54489, 't': 54490, 'i': 'interacts with'},
#  55172: {'@id': 55172, 's': 54489, 't': 54491, 'i': 'interacts with'},
#  55171: {'@id': 55171, 's': 54489, 't': 54492, 'i': 'interacts with'},
#  55170: {'@id': 55170, 's': 54489, 't': 54493, 'i': 'interacts with'},
#  55169: {'@id': 55169, 's': 54489, 't': 54494, 'i': 'interacts with'},
#  55168: {'@id': 55168, 's': 54489, 't': 54495, 'i': 'interacts with'},
#  55167: {'@id': 55167, 's': 54489, 't': 54496, 'i': 'interacts with'},
#  55166: {'@id': 55166, 's': 54489, 't': 54497, 'i': 'interacts with'},
#  55165: {'@id': 55165, 's': 54489, 't': 54498, 'i': 'interacts with'},
#  55164: {'@id': 55164, 's': 54489, 't': 54499, 'i': 'interacts with'},
#  55163: {'@id': 55163, 's': 54489, 't': 54500, 'i': 'interacts with'},
#  55162: {'@id': 55162, 's': 54489, 't': 54501, 'i': 'interacts with'},
#  55161: {'@id': 55161, 's': 54489, 't': 54502, 'i': 'interacts with'},
#  55160: {'@id': 55160, 's': 54489, 't': 54503, 'i': 'interacts with'},
#  55159: {'@id': 55159, 's': 54489, 't': 54504, 'i': 'interacts with'},
#  55158: {'@id': 55158, 's': 54489, 't': 54505, 'i': 'interacts with'},
#  55157: {'@id': 55157, 's': 54489, 't': 54506, 'i': 'interacts with'},
#  55156: {'@id': 55156, 's': 54489, 't': 54507, 'i': 'interacts with'},
#  55155: {'@id': 55155, 's': 54489, 't': 54508, 'i': 'interacts with'},
#  55154: {'@id': 55154, 's': 54489, 't': 54509, 'i': 'interacts with'},
#  55153: {'@id': 55153, 's': 54489, 't': 54510, 'i': 'interacts with'},
#  55152: {'@id': 55152, 's': 54489, 't': 54511, 'i': 'interacts with'},
#  55151: {'@id': 55151, 's': 54489, 't': 54512, 'i': 'interacts with'},
#  55150: {'@id': 55150, 's': 54489, 't': 54513, 'i': 'interacts with'},
#  55149: {'@id': 55149, 's': 54489, 't': 54514, 'i': 'interacts with'},
#  55148: {'@id': 55148, 's': 54489, 't': 54515, 'i': 'interacts with'},
#  55147: {'@id': 55147, 's': 54477, 't': 54478, 'i': 'interacts with'},
#  55146: {'@id': 55146, 's': 54477, 't': 54479, 'i': 'interacts with'},
#  55145: {'@id': 55145, 's': 54477, 't': 54480, 'i': 'interacts with'},
#  55144: {'@id': 55144, 's': 54477, 't': 54481, 'i': 'interacts with'},
#  55143: {'@id': 55143, 's': 54477, 't': 54482, 'i': 'interacts with'},
#  55142: {'@id': 55142, 's': 54477, 't': 54483, 'i': 'interacts with'},
#  55141: {'@id': 55141, 's': 54477, 't': 54484, 'i': 'interacts with'},
#  55140: {'@id': 55140, 's': 54477, 't': 54485, 'i': 'interacts with'},
#  55139: {'@id': 55139, 's': 54477, 't': 54486, 'i': 'interacts with'},
#  55138: {'@id': 55138, 's': 54477, 't': 54487, 'i': 'interacts with'},
#  55137: {'@id': 55137, 's': 54477, 't': 54488, 'i': 'interacts with'},
#  55136: {'@id': 55136, 's': 54476, 't': 54430, 'i': 'interacts with'},
#  55135: {'@id': 55135, 's': 54475, 't': 54434, 'i': 'interacts with'},
#  55134: {'@id': 55134, 's': 54429, 't': 54430, 'i': 'interacts with'},
#  55133: {'@id': 55133, 's': 54429, 't': 54431, 'i': 'interacts with'},
#  55132: {'@id': 55132, 's': 54429, 't': 54432, 'i': 'interacts with'},
#  55131: {'@id': 55131, 's': 54429, 't': 54433, 'i': 'interacts with'},
#  55130: {'@id': 55130, 's': 54429, 't': 54434, 'i': 'interacts with'},
#  55129: {'@id': 55129, 's': 54429, 't': 54435, 'i': 'interacts with'},
#  55128: {'@id': 55128, 's': 54429, 't': 54436, 'i': 'interacts with'},
#  55127: {'@id': 55127, 's': 54429, 't': 54437, 'i': 'interacts with'},
#  55126: {'@id': 55126, 's': 54429, 't': 54438, 'i': 'interacts with'},
#  55125: {'@id': 55125, 's': 54429, 't': 54439, 'i': 'interacts with'},
#  55124: {'@id': 55124, 's': 54429, 't': 54440, 'i': 'interacts with'},
#  55123: {'@id': 55123, 's': 54429, 't': 54441, 'i': 'interacts with'},
#  55122: {'@id': 55122, 's': 54429, 't': 54442, 'i': 'interacts with'},
#  55121: {'@id': 55121, 's': 54429, 't': 54443, 'i': 'interacts with'},
#  55120: {'@id': 55120, 's': 54429, 't': 54444, 'i': 'interacts with'},
#  55119: {'@id': 55119, 's': 54429, 't': 54445, 'i': 'interacts with'},
#  55118: {'@id': 55118, 's': 54429, 't': 54446, 'i': 'interacts with'},
#  55117: {'@id': 55117, 's': 54429, 't': 54447, 'i': 'interacts with'},
#  55116: {'@id': 55116, 's': 54429, 't': 54448, 'i': 'interacts with'},
#  55115: {'@id': 55115, 's': 54429, 't': 54449, 'i': 'interacts with'},
#  55114: {'@id': 55114, 's': 54429, 't': 54450, 'i': 'interacts with'},
#  55113: {'@id': 55113, 's': 54429, 't': 54451, 'i': 'interacts with'},
#  55112: {'@id': 55112, 's': 54429, 't': 54452, 'i': 'interacts with'},
#  55111: {'@id': 55111, 's': 54429, 't': 54453, 'i': 'interacts with'},
#  55110: {'@id': 55110, 's': 54429, 't': 54454, 'i': 'interacts with'},
#  55109: {'@id': 55109, 's': 54429, 't': 54455, 'i': 'interacts with'},
#  55108: {'@id': 55108, 's': 54429, 't': 54456, 'i': 'interacts with'},
#  55107: {'@id': 55107, 's': 54429, 't': 54457, 'i': 'interacts with'},
#  55106: {'@id': 55106, 's': 54429, 't': 54458, 'i': 'interacts with'},
#  55105: {'@id': 55105, 's': 54429, 't': 54459, 'i': 'interacts with'},
#  55104: {'@id': 55104, 's': 54429, 't': 54460, 'i': 'interacts with'},
#  55103: {'@id': 55103, 's': 54429, 't': 54461, 'i': 'interacts with'},
#  55102: {'@id': 55102, 's': 54429, 't': 54462, 'i': 'interacts with'},
#  55101: {'@id': 55101, 's': 54429, 't': 54463, 'i': 'interacts with'},
#  55100: {'@id': 55100, 's': 54429, 't': 54464, 'i': 'interacts with'},
#  55099: {'@id': 55099, 's': 54429, 't': 54465, 'i': 'interacts with'},
#  55098: {'@id': 55098, 's': 54429, 't': 54466, 'i': 'interacts with'},
#  55097: {'@id': 55097, 's': 54429, 't': 54467, 'i': 'interacts with'},
#  55096: {'@id': 55096, 's': 54429, 't': 54468, 'i': 'interacts with'},
#  55095: {'@id': 55095, 's': 54429, 't': 54469, 'i': 'interacts with'},
#  55094: {'@id': 55094, 's': 54429, 't': 54470, 'i': 'interacts with'},
#  55093: {'@id': 55093, 's': 54429, 't': 54471, 'i': 'interacts with'},
#  55092: {'@id': 55092, 's': 54429, 't': 54472, 'i': 'interacts with'},
#  55091: {'@id': 55091, 's': 54429, 't': 54473, 'i': 'interacts with'},
#  55090: {'@id': 55090, 's': 54429, 't': 54474, 'i': 'interacts with'},
#  55089: {'@id': 55089, 's': 54429, 't': 54475, 'i': 'interacts with'},
#  55088: {'@id': 55088, 's': 54429, 't': 54476, 'i': 'interacts with'},
#  55087: {'@id': 55087, 's': 54426, 't': 54427, 'i': 'interacts with'},
#  55086: {'@id': 55086, 's': 54426, 't': 54428, 'i': 'interacts with'},
#  55085: {'@id': 55085, 's': 54423, 't': 54424, 'i': 'interacts with'},
#  55084: {'@id': 55084, 's': 54422, 't': 54423, 'i': 'interacts with'},
#  55083: {'@id': 55083, 's': 54422, 't': 54424, 'i': 'interacts with'},
#  55082: {'@id': 55082, 's': 54422, 't': 54425, 'i': 'interacts with'},
#  55081: {'@id': 55081, 's': 54420, 't': 54421, 'i': 'interacts with'},
#  55080: {'@id': 55080, 's': 54417, 't': 54415, 'i': 'interacts with'},
#  55079: {'@id': 55079, 's': 54411, 't': 54412, 'i': 'interacts with'},
#  55078: {'@id': 55078, 's': 54411, 't': 54413, 'i': 'interacts with'},
#  55077: {'@id': 55077, 's': 54411, 't': 54414, 'i': 'interacts with'},
#  55076: {'@id': 55076, 's': 54411, 't': 54415, 'i': 'interacts with'},
#  55075: {'@id': 55075, 's': 54411, 't': 54416, 'i': 'interacts with'},
#  55074: {'@id': 55074, 's': 54411, 't': 54417, 'i': 'interacts with'},
#  55073: {'@id': 55073, 's': 54411, 't': 54418, 'i': 'interacts with'},
#  55072: {'@id': 55072, 's': 54411, 't': 54419, 'i': 'interacts with'},
#  55071: {'@id': 55071, 's': 54410, 't': 54409, 'i': 'interacts with'},
#  55070: {'@id': 55070, 's': 54410, 't': 54406, 'i': 'interacts with'},
#  55069: {'@id': 55069, 's': 54409, 't': 54406, 'i': 'interacts with'},
#  55068: {'@id': 55068, 's': 54409, 't': 54408, 'i': 'interacts with'},
#  55067: {'@id': 55067, 's': 54408, 't': 54410, 'i': 'interacts with'},
#  55066: {'@id': 55066, 's': 54406, 't': 54408, 'i': 'interacts with'},
#  55065: {'@id': 55065, 's': 54403, 't': 54410, 'i': 'interacts with'},
#  55064: {'@id': 55064, 's': 54403, 't': 54409, 'i': 'interacts with'},
#  55063: {'@id': 55063, 's': 54403, 't': 54408, 'i': 'interacts with'},
#  55062: {'@id': 55062, 's': 54403, 't': 54406, 'i': 'interacts with'},
#  55061: {'@id': 55061, 's': 54401, 't': 54402, 'i': 'interacts with'},
#  55060: {'@id': 55060, 's': 54401, 't': 54403, 'i': 'interacts with'},
#  55059: {'@id': 55059, 's': 54401, 't': 54404, 'i': 'interacts with'},
#  55058: {'@id': 55058, 's': 54401, 't': 54405, 'i': 'interacts with'},
#  55057: {'@id': 55057, 's': 54401, 't': 54406, 'i': 'interacts with'},
#  55056: {'@id': 55056, 's': 54401, 't': 54407, 'i': 'interacts with'},
#  55055: {'@id': 55055, 's': 54401, 't': 54408, 'i': 'interacts with'},
#  55054: {'@id': 55054, 's': 54401, 't': 54409, 'i': 'interacts with'},
#  55053: {'@id': 55053, 's': 54401, 't': 54410, 'i': 'interacts with'},
#  55052: {'@id': 55052, 's': 54400, 't': 54386, 'i': 'interacts with'},
#  55051: {'@id': 55051, 's': 54400, 't': 54387, 'i': 'interacts with'},
#  55050: {'@id': 55050, 's': 54398, 't': 54389, 'i': 'interacts with'},
#  55049: {'@id': 55049, 's': 54398, 't': 54397, 'i': 'interacts with'},
#  55048: {'@id': 55048, 's': 54392, 't': 54398, 'i': 'interacts with'},
#  55047: {'@id': 55047, 's': 54392, 't': 54389, 'i': 'interacts with'},
#  55046: {'@id': 55046, 's': 54392, 't': 54397, 'i': 'interacts with'},
#  55045: {'@id': 55045, 's': 54389, 't': 54397, 'i': 'interacts with'},
#  55044: {'@id': 55044, 's': 54388, 't': 54392, 'i': 'interacts with'},
#  55043: {'@id': 55043, 's': 54388, 't': 54398, 'i': 'interacts with'},
#  55042: {'@id': 55042, 's': 54388, 't': 54389, 'i': 'interacts with'},
#  55041: {'@id': 55041, 's': 54388, 't': 54397, 'i': 'interacts with'},
#  55040: {'@id': 55040, 's': 54387, 't': 54386, 'i': 'interacts with'},
#  55039: {'@id': 55039, 's': 54384, 't': 54385, 'i': 'interacts with'},
#  55038: {'@id': 55038, 's': 54384, 't': 54386, 'i': 'interacts with'},
#  55037: {'@id': 55037, 's': 54384, 't': 54387, 'i': 'interacts with'},
#  55036: {'@id': 55036, 's': 54384, 't': 54388, 'i': 'interacts with'},
#  55035: {'@id': 55035, 's': 54384, 't': 54389, 'i': 'interacts with'},
#  55034: {'@id': 55034, 's': 54384, 't': 54390, 'i': 'interacts with'},
#  55033: {'@id': 55033, 's': 54384, 't': 54391, 'i': 'interacts with'},
#  55032: {'@id': 55032, 's': 54384, 't': 54392, 'i': 'interacts with'},
#  55031: {'@id': 55031, 's': 54384, 't': 54393, 'i': 'interacts with'},
#  55030: {'@id': 55030, 's': 54384, 't': 54394, 'i': 'interacts with'},
#  55029: {'@id': 55029, 's': 54384, 't': 54395, 'i': 'interacts with'},
#  55028: {'@id': 55028, 's': 54384, 't': 54396, 'i': 'interacts with'},
#  55027: {'@id': 55027, 's': 54384, 't': 54397, 'i': 'interacts with'},
#  55026: {'@id': 55026, 's': 54384, 't': 54398, 'i': 'interacts with'},
#  55025: {'@id': 55025, 's': 54384, 't': 54399, 'i': 'interacts with'},
#  55024: {'@id': 55024, 's': 54384, 't': 54400, 'i': 'interacts with'},
#  55023: {'@id': 55023, 's': 54383, 't': 54381, 'i': 'interacts with'},
#  55022: {'@id': 55022, 's': 54382, 't': 54377, 'i': 'interacts with'},
#  55021: {'@id': 55021, 's': 54382, 't': 54376, 'i': 'interacts with'},
#  55020: {'@id': 55020, 's': 54382, 't': 54371, 'i': 'interacts with'},
#  55019: {'@id': 55019, 's': 54380, 't': 54366, 'i': 'interacts with'},
#  55018: {'@id': 55018, 's': 54380, 't': 54383, 'i': 'interacts with'},
#  55017: {'@id': 55017, 's': 54380, 't': 54381, 'i': 'interacts with'},
#  55016: {'@id': 55016, 's': 54378, 't': 54370, 'i': 'interacts with'},
#  55015: {'@id': 55015, 's': 54378, 't': 54373, 'i': 'interacts with'},
#  55014: {'@id': 55014, 's': 54377, 't': 54376, 'i': 'interacts with'},
#  55013: {'@id': 55013, 's': 54377, 't': 54371, 'i': 'interacts with'},
#  55012: {'@id': 55012, 's': 54376, 't': 54371, 'i': 'interacts with'},
#  55011: {'@id': 55011, 's': 54370, 't': 54373, 'i': 'interacts with'},
#  55010: {'@id': 55010, 's': 54368, 't': 54369, 'i': 'interacts with'},
#  55009: {'@id': 55009, 's': 54366, 't': 54383, 'i': 'interacts with'},
#  55008: {'@id': 55008, 's': 54366, 't': 54381, 'i': 'interacts with'},
#  55007: {'@id': 55007, 's': 54365, 't': 54364, 'i': 'interacts with'},
#  55006: {'@id': 55006, 's': 54365, 't': 54361, 'i': 'interacts with'},
#  55005: {'@id': 55005, 's': 54364, 't': 54361, 'i': 'interacts with'},
#  55004: {'@id': 55004, 's': 54359, 't': 54360, 'i': 'interacts with'},
#  55003: {'@id': 55003, 's': 54359, 't': 54361, 'i': 'interacts with'},
#  55002: {'@id': 55002, 's': 54359, 't': 54362, 'i': 'interacts with'},
#  55001: {'@id': 55001, 's': 54359, 't': 54363, 'i': 'interacts with'},
#  55000: {'@id': 55000, 's': 54359, 't': 54364, 'i': 'interacts with'},
#  54999: {'@id': 54999, 's': 54359, 't': 54365, 'i': 'interacts with'},
#  54998: {'@id': 54998, 's': 54359, 't': 54366, 'i': 'interacts with'},
#  54997: {'@id': 54997, 's': 54359, 't': 54367, 'i': 'interacts with'},
#  54996: {'@id': 54996, 's': 54359, 't': 54368, 'i': 'interacts with'},
#  54995: {'@id': 54995, 's': 54359, 't': 54369, 'i': 'interacts with'},
#  54994: {'@id': 54994, 's': 54359, 't': 54370, 'i': 'interacts with'},
#  54993: {'@id': 54993, 's': 54359, 't': 54371, 'i': 'interacts with'},
#  54992: {'@id': 54992, 's': 54359, 't': 54372, 'i': 'interacts with'},
#  54991: {'@id': 54991, 's': 54359, 't': 54373, 'i': 'interacts with'},
#  54990: {'@id': 54990, 's': 54359, 't': 54374, 'i': 'interacts with'},
#  54989: {'@id': 54989, 's': 54359, 't': 54375, 'i': 'interacts with'},
#  54988: {'@id': 54988, 's': 54359, 't': 54376, 'i': 'interacts with'},
#  54987: {'@id': 54987, 's': 54359, 't': 54377, 'i': 'interacts with'},
#  54986: {'@id': 54986, 's': 54359, 't': 54378, 'i': 'interacts with'},
#  54985: {'@id': 54985, 's': 54359, 't': 54379, 'i': 'interacts with'},
#  54984: {'@id': 54984, 's': 54359, 't': 54380, 'i': 'interacts with'},
#  54983: {'@id': 54983, 's': 54359, 't': 54381, 'i': 'interacts with'},
#  54982: {'@id': 54982, 's': 54359, 't': 54382, 'i': 'interacts with'},
#  54981: {'@id': 54981, 's': 54359, 't': 54383, 'i': 'interacts with'},
#  54980: {'@id': 54980, 's': 54341, 't': 54342, 'i': 'interacts with'},
#  54979: {'@id': 54979, 's': 54327, 't': 54328, 'i': 'interacts with'},
#  54978: {'@id': 54978, 's': 54327, 't': 54329, 'i': 'interacts with'},
#  54977: {'@id': 54977, 's': 54327, 't': 54330, 'i': 'interacts with'},
#  54976: {'@id': 54976, 's': 54327, 't': 54331, 'i': 'interacts with'},
#  54975: {'@id': 54975, 's': 54327, 't': 54332, 'i': 'interacts with'},
#  54974: {'@id': 54974, 's': 54327, 't': 54333, 'i': 'interacts with'},
#  54973: {'@id': 54973, 's': 54327, 't': 54334, 'i': 'interacts with'},
#  54972: {'@id': 54972, 's': 54327, 't': 54335, 'i': 'interacts with'},
#  54971: {'@id': 54971, 's': 54327, 't': 54336, 'i': 'interacts with'},
#  54970: {'@id': 54970, 's': 54327, 't': 54337, 'i': 'interacts with'},
#  54969: {'@id': 54969, 's': 54327, 't': 54338, 'i': 'interacts with'},
#  54968: {'@id': 54968, 's': 54327, 't': 54339, 'i': 'interacts with'},
#  54967: {'@id': 54967, 's': 54327, 't': 54340, 'i': 'interacts with'},
#  54966: {'@id': 54966, 's': 54327, 't': 54341, 'i': 'interacts with'},
#  54965: {'@id': 54965, 's': 54327, 't': 54342, 'i': 'interacts with'},
#  54964: {'@id': 54964, 's': 54327, 't': 54343, 'i': 'interacts with'},
#  54963: {'@id': 54963, 's': 54327, 't': 54344, 'i': 'interacts with'},
#  54962: {'@id': 54962, 's': 54327, 't': 54345, 'i': 'interacts with'},
#  54961: {'@id': 54961, 's': 54327, 't': 54346, 'i': 'interacts with'},
#  54960: {'@id': 54960, 's': 54327, 't': 54347, 'i': 'interacts with'},
#  54959: {'@id': 54959, 's': 54327, 't': 54348, 'i': 'interacts with'},
#  54958: {'@id': 54958, 's': 54327, 't': 54349, 'i': 'interacts with'},
#  54957: {'@id': 54957, 's': 54327, 't': 54350, 'i': 'interacts with'},
#  54956: {'@id': 54956, 's': 54327, 't': 54351, 'i': 'interacts with'},
#  54955: {'@id': 54955, 's': 54327, 't': 54352, 'i': 'interacts with'},
#  54954: {'@id': 54954, 's': 54327, 't': 54353, 'i': 'interacts with'},
#  54953: {'@id': 54953, 's': 54327, 't': 54354, 'i': 'interacts with'},
#  54952: {'@id': 54952, 's': 54327, 't': 54355, 'i': 'interacts with'},
#  54875: {'@id': 54875, 's': 54272, 't': 54269, 'i': 'interacts with'},
#  54874: {'@id': 54874, 's': 54272, 't': 54288, 'i': 'interacts with'},
#  54873: {'@id': 54873, 's': 54271, 't': 54273, 'i': 'interacts with'},
#  54872: {'@id': 54872, 's': 54271, 't': 54278, 'i': 'interacts with'},
#  54871: {'@id': 54871, 's': 54271, 't': 54269, 'i': 'interacts with'},
#  54870: {'@id': 54870, 's': 54271, 't': 54288, 'i': 'interacts with'},
#  54869: {'@id': 54869, 's': 54271, 't': 54272, 'i': 'interacts with'},
#  54868: {'@id': 54868, 's': 54269, 't': 54273, 'i': 'interacts with'},
#  54867: {'@id': 54867, 's': 54269, 't': 54278, 'i': 'interacts with'},
#  54866: {'@id': 54866, 's': 54263, 't': 54264, 'i': 'interacts with'},
#  54865: {'@id': 54865, 's': 54262, 't': 54264, 'i': 'interacts with'},
#  54864: {'@id': 54864, 's': 54262, 't': 54263, 'i': 'interacts with'},
#  54863: {'@id': 54863, 's': 54261, 't': 54273, 'i': 'interacts with'},
#  54862: {'@id': 54862, 's': 54261, 't': 54277, 'i': 'interacts with'},
#  54861: {'@id': 54861, 's': 54261, 't': 54255, 'i': 'interacts with'},
#  54860: {'@id': 54860, 's': 54261, 't': 54291, 'i': 'interacts with'},
#  54859: {'@id': 54859, 's': 54261, 't': 54278, 'i': 'interacts with'},
#  54858: {'@id': 54858, 's': 54261, 't': 54272, 'i': 'interacts with'},
#  54857: {'@id': 54857, 's': 54261, 't': 54288, 'i': 'interacts with'},
#  54856: {'@id': 54856, 's': 54261, 't': 54271, 'i': 'interacts with'},
#  54855: {'@id': 54855, 's': 54261, 't': 54269, 'i': 'interacts with'},
#  54854: {'@id': 54854, 's': 54258, 't': 54257, 'i': 'interacts with'},
#  54853: {'@id': 54853, 's': 54257, 't': 54259, 'i': 'interacts with'},
#  54852: {'@id': 54852, 's': 54256, 't': 54273, 'i': 'interacts with'},
#  54851: {'@id': 54851, 's': 54256, 't': 54277, 'i': 'interacts with'},
#  54850: {'@id': 54850, 's': 54256, 't': 54255, 'i': 'interacts with'},
#  54849: {'@id': 54849, 's': 54256, 't': 54291, 'i': 'interacts with'},
#  54848: {'@id': 54848, 's': 54256, 't': 54261, 'i': 'interacts with'},
#  54847: {'@id': 54847, 's': 54256, 't': 54278, 'i': 'interacts with'},
#  54846: {'@id': 54846, 's': 54256, 't': 54269, 'i': 'interacts with'},
#  54845: {'@id': 54845, 's': 54256, 't': 54288, 'i': 'interacts with'},
#  54844: {'@id': 54844, 's': 54256, 't': 54272, 'i': 'interacts with'},
#  54843: {'@id': 54843, 's': 54256, 't': 54271, 'i': 'interacts with'},
#  54842: {'@id': 54842, 's': 54255, 't': 54278, 'i': 'interacts with'},
#  54841: {'@id': 54841, 's': 54255, 't': 54272, 'i': 'interacts with'},
#  54840: {'@id': 54840, 's': 54255, 't': 54288, 'i': 'interacts with'},
#  54839: {'@id': 54839, 's': 54255, 't': 54273, 'i': 'interacts with'},
#  54723: {'@id': 54723, 's': 54191, 't': 54052, 'i': 'c-c'},
#  54722: {'@id': 54722, 's': 54191, 't': 54183, 'i': 'c-c'},
#  54721: {'@id': 54721, 's': 54191, 't': 54169, 'i': 'c-c'},
#  54720: {'@id': 54720, 's': 54191, 't': 54146, 'i': 'c-c'},
#  54719: {'@id': 54719, 's': 54191, 't': 54149, 'i': 'c-c'},
#  54718: {'@id': 54718, 's': 54191, 't': 54189, 'i': 'c-c'},
#  54717: {'@id': 54717, 's': 54191, 't': 54194, 'i': 'c-c'},
#  54716: {'@id': 54716, 's': 54191, 't': 54186, 'i': 'c-c'},
#  54715: {'@id': 54715, 's': 54190, 't': 54196, 'i': 'c-c'},
#  54714: {'@id': 54714, 's': 54190, 't': 54181, 'i': 'c-c'},
#  54713: {'@id': 54713, 's': 54190, 't': 54098, 'i': 'c-c'},
#  54712: {'@id': 54712, 's': 54190, 't': 54157, 'i': 'c-c'},
#  54711: {'@id': 54711, 's': 54190, 't': 54156, 'i': 'c-c'},
#  54710: {'@id': 54710, 's': 54190, 't': 54160, 'i': 'c-c'},
#  54709: {'@id': 54709, 's': 54190, 't': 54137, 'i': 'c-c'},
#  54708: {'@id': 54708, 's': 54189, 't': 54101, 'i': 'c-c'},
#  54707: {'@id': 54707, 's': 54189, 't': 54104, 'i': 'c-c'},
#  54706: {'@id': 54706, 's': 54189, 't': 54088, 'i': 'c-c'},
#  54705: {'@id': 54705, 's': 54189, 't': 54061, 'i': 'c-c'},
#  54704: {'@id': 54704, 's': 54189, 't': 54123, 'i': 'c-c'},
#  54703: {'@id': 54703, 's': 54189, 't': 54113, 'i': 'c-c'},
#  54702: {'@id': 54702, 's': 54189, 't': 54122, 'i': 'c-c'},
#  54701: {'@id': 54701, 's': 54189, 't': 54119, 'i': 'c-c'},
#  54700: {'@id': 54700, 's': 54189, 't': 54173, 'i': 'c-c'},
#  54699: {'@id': 54699, 's': 54189, 't': 54184, 'i': 'c-c'},
#  54698: {'@id': 54698, 's': 54189, 't': 54153, 'i': 'c-c'},
#  54697: {'@id': 54697, 's': 54189, 't': 54204, 'i': 'c-c'},
#  54696: {'@id': 54696, 's': 54189, 't': 54208, 'i': 'c-c'},
#  54695: {'@id': 54695, 's': 54189, 't': 54207, 'i': 'c-c'},
#  54694: {'@id': 54694, 's': 54189, 't': 54209, 'i': 'c-c'},
#  54693: {'@id': 54693, 's': 54189, 't': 54224, 'i': 'c-c'},
#  54692: {'@id': 54692, 's': 54189, 't': 54221, 'i': 'c-c'},
#  54691: {'@id': 54691, 's': 54189, 't': 54227, 'i': 'c-c'},
#  54690: {'@id': 54690, 's': 54189, 't': 54229, 'i': 'c-c'},
#  54689: {'@id': 54689, 's': 54189, 't': 54049, 'i': 'c-c'},
#  54688: {'@id': 54688, 's': 54189, 't': 54048, 'i': 'c-c'},
#  54687: {'@id': 54687, 's': 54189, 't': 54054, 'i': 'c-c'},
#  54686: {'@id': 54686, 's': 54189, 't': 54217, 'i': 'c-c'},
#  54685: {'@id': 54685, 's': 54189, 't': 54059, 'i': 'c-c'},
#  54684: {'@id': 54684, 's': 54189, 't': 54063, 'i': 'c-c'},
#  54683: {'@id': 54683, 's': 54189, 't': 54068, 'i': 'c-c'},
#  54682: {'@id': 54682, 's': 54189, 't': 54050, 'i': 'c-c'},
#  54681: {'@id': 54681, 's': 54189, 't': 54112, 'i': 'c-c'},
#  54680: {'@id': 54680, 's': 54189, 't': 54142, 'i': 'c-c'},
#  54679: {'@id': 54679, 's': 54189, 't': 54058, 'i': 'c-c'},
#  54678: {'@id': 54678, 's': 54189, 't': 54097, 'i': 'c-c'},
#  54677: {'@id': 54677, 's': 54189, 't': 54170, 'i': 'c-c'},
#  54676: {'@id': 54676, 's': 54189, 't': 54216, 'i': 'c-c'},
#  54675: {'@id': 54675, 's': 54189, 't': 54215, 'i': 'c-c'},
#  54674: {'@id': 54674, 's': 54189, 't': 54214, 'i': 'c-c'},
#  54673: {'@id': 54673, 's': 54189, 't': 54213, 'i': 'c-c'},
#  54672: {'@id': 54672, 's': 54188, 't': 54159, 'i': 'c-c'},
#  54671: {'@id': 54671, 's': 54188, 't': 54094, 'i': 'c-c'},
#  54670: {'@id': 54670, 's': 54188, 't': 54072, 'i': 'c-c'},
#  54669: {'@id': 54669, 's': 54188, 't': 54077, 'i': 'c-c'},
#  54668: {'@id': 54668, 's': 54188, 't': 54192, 'i': 'c-c'},
#  54667: {'@id': 54667, 's': 54188, 't': 54195, 'i': 'c-c'},
#  54666: {'@id': 54666, 's': 54188, 't': 54200, 'i': 'c-c'},
#  54665: {'@id': 54665, 's': 54188, 't': 54182, 'i': 'c-c'},
#  54664: {'@id': 54664, 's': 54187, 't': 54188, 'i': 'c-c'},
#  54663: {'@id': 54663, 's': 54186, 't': 54163, 'i': 'c-c'},
#  54662: {'@id': 54662, 's': 54186, 't': 54100, 'i': 'c-c'},
#  54661: {'@id': 54661, 's': 54185, 't': 54067, 'i': 'c-c'},
#  54660: {'@id': 54660, 's': 54185, 't': 54210, 'i': 'c-c'},
#  54659: {'@id': 54659, 's': 54185, 't': 54162, 'i': 'c-c'},
#  54658: {'@id': 54658, 's': 54184, 't': 54158, 'i': 'c-c'},
#  54657: {'@id': 54657, 's': 54184, 't': 54057, 'i': 'c-c'},
#  54656: {'@id': 54656, 's': 54183, 't': 54164, 'i': 'c-c'},
#  54655: {'@id': 54655, 's': 54183, 't': 54136, 'i': 'c-c'},
#  54654: {'@id': 54654, 's': 54182, 't': 54043, 'i': 'c-c'},
#  54653: {'@id': 54653, 's': 54182, 't': 54053, 'i': 'c-c'},
#  54652: {'@id': 54652, 's': 54181, 't': 54140, 'i': 'c-c'},
#  54651: {'@id': 54651, 's': 54181, 't': 54144, 'i': 'c-c'},
#  54650: {'@id': 54650, 's': 54181, 't': 54110, 'i': 'c-c'},
#  54649: {'@id': 54649, 's': 54180, 't': 54169, 'i': 'c-c'},
#  54648: {'@id': 54648, 's': 54180, 't': 54154, 'i': 'c-c'},
#  54647: {'@id': 54647, 's': 54180, 't': 54080, 'i': 'c-c'},
#  54646: {'@id': 54646, 's': 54179, 't': 54117, 'i': 'c-c'},
#  54645: {'@id': 54645, 's': 54179, 't': 54118, 'i': 'c-c'},
#  54644: {'@id': 54644, 's': 54178, 't': 54185, 'i': 'c-c'},
#  54643: {'@id': 54643, 's': 54178, 't': 54095, 'i': 'c-c'},
#  54642: {'@id': 54642, 's': 54177, 't': 54179, 'i': 'c-c'},
#  54641: {'@id': 54641, 's': 54177, 't': 54206, 'i': 'c-c'},
#  54640: {'@id': 54640, 's': 54176, 't': 54167, 'i': 'c-c'},
#  54639: {'@id': 54639, 's': 54176, 't': 54165, 'i': 'c-c'},
#  54638: {'@id': 54638, 's': 54175, 't': 54084, 'i': 'c-c'},
#  54637: {'@id': 54637, 's': 54175, 't': 54090, 'i': 'c-c'},
#  54636: {'@id': 54636, 's': 54175, 't': 54147, 'i': 'c-c'},
#  54635: {'@id': 54635, 's': 54175, 't': 54107, 'i': 'c-c'},
#  54634: {'@id': 54634, 's': 54174, 't': 54120, 'i': 'c-c'},
#  54633: {'@id': 54633, 's': 54174, 't': 54148, 'i': 'c-c'},
#  54632: {'@id': 54632, 's': 54174, 't': 54201, 'i': 'c-c'},
#  54631: {'@id': 54631, 's': 54174, 't': 54178, 'i': 'c-c'},
#  54630: {'@id': 54630, 's': 54173, 't': 54070, 'i': 'c-c'},
#  54629: {'@id': 54629, 's': 54173, 't': 54228, 'i': 'c-c'},
#  54628: {'@id': 54628, 's': 54173, 't': 54177, 'i': 'c-c'},
#  54627: {'@id': 54627, 's': 54172, 't': 54096, 'i': 'c-c'},
#  54626: {'@id': 54626, 's': 54172, 't': 54130, 'i': 'c-c'},
#  54625: {'@id': 54625, 's': 54172, 't': 54155, 'i': 'c-c'},
#  54624: {'@id': 54624, 's': 54172, 't': 54092, 'i': 'c-c'},
#  54623: {'@id': 54623, 's': 54171, 't': 54222, 'i': 'c-c'},
#  54622: {'@id': 54622, 's': 54171, 't': 54232, 'i': 'c-c'},
#  54621: {'@id': 54621, 's': 54171, 't': 54046, 'i': 'c-c'},
#  54620: {'@id': 54620, 's': 54169, 't': 54150, 'i': 'c-c'},
#  54619: {'@id': 54619, 's': 54166, 't': 54125, 'i': 'c-c'},
#  54618: {'@id': 54618, 's': 54166, 't': 54108, 'i': 'c-c'},
#  54617: {'@id': 54617, 's': 54164, 't': 54082, 'i': 'c-c'},
#  54616: {'@id': 54616, 's': 54164, 't': 54153, 'i': 'c-c'},
#  54615: {'@id': 54615, 's': 54162, 't': 54087, 'i': 'c-c'},
#  54614: {'@id': 54614, 's': 54162, 't': 54051, 'i': 'c-c'},
#  54613: {'@id': 54613, 's': 54162, 't': 54045, 'i': 'c-c'},
#  54612: {'@id': 54612, 's': 54160, 't': 54075, 'i': 'c-c'},
#  54611: {'@id': 54611, 's': 54160, 't': 54139, 'i': 'c-c'},
#  54610: {'@id': 54610, 's': 54158, 't': 54126, 'i': 'c-c'},
#  54609: {'@id': 54609, 's': 54158, 't': 54131, 'i': 'c-c'},
#  54608: {'@id': 54608, 's': 54153, 't': 54086, 'i': 'c-c'},
#  54607: {'@id': 54607, 's': 54153, 't': 54089, 'i': 'c-c'},
#  54606: {'@id': 54606, 's': 54152, 't': 54111, 'i': 'c-c'},
#  54605: {'@id': 54605, 's': 54152, 't': 54064, 'i': 'c-c'},
#  54604: {'@id': 54604, 's': 54146, 't': 54151, 'i': 'c-c'},
#  54603: {'@id': 54603, 's': 54146, 't': 54225, 'i': 'c-c'},
#  54602: {'@id': 54602, 's': 54143, 't': 54115, 'i': 'c-c'},
#  54601: {'@id': 54601, 's': 54143, 't': 54121, 'i': 'c-c'},
#  54600: {'@id': 54600, 's': 54142, 't': 54066, 'i': 'c-c'},
#  54599: {'@id': 54599, 's': 54142, 't': 54132, 'i': 'c-c'},
#  54598: {'@id': 54598, 's': 54138, 't': 54076, 'i': 'c-c'},
#  54597: {'@id': 54597, 's': 54138, 't': 54052, 'i': 'c-c'},
#  54596: {'@id': 54596, 's': 54096, 't': 54093, 'i': 'c-c'},
#  54595: {'@id': 54595, 's': 54094, 't': 54096, 'i': 'c-c'},
#  54594: {'@id': 54594, 's': 54094, 't': 54093, 'i': 'c-c'},
#  54593: {'@id': 54593, 's': 54080, 't': 54202, 'i': 'c-c'},
#  54592: {'@id': 54592, 's': 54075, 't': 54091, 'i': 'c-c'}}

# %%
#node_items = hierarchy_network.nodes.items()
#node_items
node_df = nice_cx_to_node_dataframe(hierarchy_network)
node_df
# Out:
#     CD_MemberList_LogSize                    CD_MemberList  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# 2                     NaN                              NaN
# 3                     NaN                              NaN
# 4                     NaN                              NaN
# ..                    ...                              ...
# 544                   2.0          FTSJ3 PRDM5 PTPRB RBM34
# 545                   2.0             AATF NGDN NOL10 Nsp8
# 546                   2.0  APOBEC3D HNRNPUL2 SRSF8 SYNCRIP
# 547                   2.0          IGFL1 LYPD4 NPTX1 NPTX2
# 548                   2.0         MRPS15 MRPS34 MRPS6 NOA1
#
#                        CD_CommunityName CD_AnnotatedMembers_SourceDB  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
# ..                                  ...                          ...
# 544                              (none)                          NaN
# 545             AATF-NGDN-NOL10 complex                        CORUM
# 546                              (none)                          NaN
# 547                              (none)                          NaN
# 548  organellar small ribosomal subunit                        GO:CC
#
#     Matching.Attribute     name  node_id Bait_Boolean  \
# 0              [BCKDK]    BCKDK    54591            0
# 1              [SBNO1]    SBNO1    54590            0
# 2              [Nsp12]    Nsp12    54589            1
# 3               [TBCA]     TBCA    54588            0
# 4              [Nsp11]    Nsp11    54587            1
# ..                 ...      ...      ...          ...
# 544          [C790751]  C790751    54047          NaN
# 545          [C790744]  C790744    54046          NaN
# 546          [C790745]  C790745    54045          NaN
# 547          [C790746]  C790746    54044          NaN
# 548          [C790747]  C790747    54043          NaN
#
#                                  CD_AnnotatedAlgorithm CD_MemberList_Size  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 544  Annotated by gProfiler [Docker: coleslawndex/c...                  4
# 545  Annotated by gProfiler [Docker: coleslawndex/c...                  4
# 546  Annotated by gProfiler [Docker: coleslawndex/c...                  4
# 547  Annotated by gProfiler [Docker: coleslawndex/c...                  4
# 548  Annotated by gProfiler [Docker: coleslawndex/c...                  4
#
#      CD_AnnotatedMembers CD_AnnotatedMembers_Size CD_Labeled  \
# 0                    NaN                      NaN        NaN
# 1                    NaN                      NaN        NaN
# 2                    NaN                      NaN        NaN
# 3                    NaN                      NaN        NaN
# 4                    NaN                      NaN        NaN
# ..                   ...                      ...        ...
# 544                  NaN                        0      false
# 545      AATF NGDN NOL10                        3       true
# 546                  NaN                        0      false
# 547                  NaN                        0      false
# 548  MRPS15 MRPS34 MRPS6                        3       true
#
#     CD_InteractorMemberOverlap CD_AnnotatedMembers_Pvalue  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 544                        0.0                        NaN
# 545                       0.75     1.3605804849833504E-11
# 546                        0.0                        NaN
# 547                       0.25                        NaN
# 548                        0.0       9.939923403735769E-8
#
#     CD_AnnotatedMembers_Overlap CD_InteractorMembers  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# ..                          ...                  ...
# 544                         0.0                  NaN
# 545                         1.0  [NGDN, AATF, NOL10]
# 546                         0.0                  NaN
# 547                         0.0              [NPTX1]
# 548                         0.1                  NaN
#
#     CD_AnnotatedMembers_SourceTerm CD_NonAnnotatedMembers
# 0                              NaN                    NaN
# 1                              NaN                    NaN
# 2                              NaN                    NaN
# 3                              NaN                    NaN
# 4                              NaN                    NaN
# ..                             ...                    ...
# 544                            NaN                    NaN
# 545                     CORUM:6313                   Nsp8
# 546                            NaN                    NaN
# 547                            NaN                    NaN
# 548                     GO:0000314                   NOA1
#
# [549 rows x 19 columns]

# %% [markdown]
# ### Connect Communities to Interactor Proteins
#
# The goal is to have the viral proteins at the core of the network, connecting to their interactors. Each interactor is in turn connected to the terms in the hierarchy to which it is _directly_ annotated. Unfortunately the direct annotations are not distinguished from the indirect in this data. We therefore need to compute that by finding the terms that contain the interactor AND that have no child node that contains the interactor
#
# We populate a dict, int_to_com in which the keys are interactors and the values are sets of communities, initiallized to empty sets.
# - for each interactor:
# -- for each community:
#     if the the interactor is in the community, add the community to the set associated with the interactor.
#
# We now prune each set of communities. For each community C in the list, iterate over the edges in the network. We only want to keep C if it has no parents, i.e. if there is any edge in which C is the target, remove it from the set.
#
# When the set is pruned, add an edge from the interactor to each remaining community.

# %%
int_to_com = {}
for interactor_name in interactor_set.items():
    int_to_com[interactor_name] = set()
    
for interactor_name, community_set in int_to_com.items():
    communities_to_remove = set()
    for edge_id, edge in hierarchy_network.edges.items():
        if edge['s'] is in community_set and edge['t'] is in community_set:
            communities_to_remove.add(edge['t'])
    communities_to_connect = community_set.difference(communities_to_remove)
    for community_id in communities_to_connect.items():
        # add edge from interactor_id to community_id
        hierarchy_network.add_edge(interactor_id)

# %%
def in_community(row, interactors):
    #print(len(row.get("CD_MemberList")))
    #result = list(set(row.get("CD_MemberList")).intersection(interactors))
    #if (len(result) > 0):
    #    print(result)
    return list(set(row.get("CD_MemberList").split()).intersection(interactors))

def community_overlap(row, interactors):
    intersection = len(set(row.get("CD_MemberList").split()).intersection(interactors))
    memberlist_size = int(row.get("CD_MemberList_Size"))
    if isinstance(memberlist_size, (int, float)):
        return intersection / memberlist_size
    else:
        return 0

def jacquard_interactors(row, interactors):
    return jaccard_similarity_sets(set(row.get("CD_MemberList").split()), interactors)
                            
node_df["CD_InteractorMembers"] = node_df.apply(lambda row: in_community(row, interactor_set), axis=1)
                            
node_df["CD_InteractorMemberOverlap"] = node_df.apply(lambda row: community_overlap(row, interactor_set), axis=1)
node_df

# append columns + name them
# Out:
#     CD_Labeled CD_AnnotatedMembers_SourceTerm CD_MemberList_Size  \
# 0        false                            NaN                  4
# 1        false                            NaN                  4
# 2        false                            NaN                  4
# 3        false                            NaN                  4
# 4        false                            NaN                  4
# ..         ...                            ...                ...
# 185       true                     GO:0005813                566
# 186       true                     GO:0031090                913
# 187       true                     GO:0012505               1487
# 188       true                  CORUM:0000000               1985
# 189       true                  CORUM:0000000               1985
#
#     CD_AnnotatedMembers_Overlap  node_id     CD_CommunityName  \
# 0                           0.0   839455               (none)
# 1                           0.0   839454               (none)
# 2                           0.0   839453               (none)
# 3                           0.0   839452               (none)
# 4                           0.0   839451               (none)
# ..                          ...      ...                  ...
# 185                       0.059   839270           centrosome
# 186                        0.09   839269   organelle membrane
# 187                       0.104   839268  endomembrane system
# 188                       0.114   839267           CORUM root
# 189                       0.114   839266           CORUM root
#
#     CD_AnnotatedMembers_Size     name  \
# 0                          0  C790791
# 1                          0  C790790
# 2                          0  C790789
# 3                          0  C790788
# 4                          0  C790787
# ..                       ...      ...
# 185                       63  C790606
# 186                      366  C790605
# 187                      564  C790604
# 188                      569  C790603
# 189                      569  C790602
#
#                                  CD_AnnotatedAlgorithm  \
# 0    Annotated by gProfiler [Docker: coleslawndex/c...
# 1    Annotated by gProfiler [Docker: coleslawndex/c...
# 2    Annotated by gProfiler [Docker: coleslawndex/c...
# 3    Annotated by gProfiler [Docker: coleslawndex/c...
# 4    Annotated by gProfiler [Docker: coleslawndex/c...
# ..                                                 ...
# 185  Annotated by gProfiler [Docker: coleslawndex/c...
# 186  Annotated by gProfiler [Docker: coleslawndex/c...
# 187  Annotated by gProfiler [Docker: coleslawndex/c...
# 188  Annotated by gProfiler [Docker: coleslawndex/c...
# 189  Annotated by gProfiler [Docker: coleslawndex/c...
#
#                                    CD_AnnotatedMembers  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 185  AKAP9 APC ARHGEF10 BIRC7 CCDC92 CCNO CCT4 CCT5...
# 186  ACAD9 ACADM ACSL3 ADGRE5 AGK AGPAT4 AGPS AIFM1...
# 187  ACSL3 ADGRE5 ADIPOQ AGPAT4 AGRN AKAP8 AKAP9 AL...
# 188  AATF ADAM9 ADIPOQ AGPS AIFM1 AKAP1 AKAP8L AKAP...
# 189  AATF ADAM9 ADIPOQ AGPS AIFM1 AKAP1 AKAP8L AKAP...
#
#                                          CD_MemberList  \
# 0                              OPALIN SCN3B TMTC4 URB2
# 1                           ENPP7 ERGIC3 IL2RA TMEM192
# 2                             CLCC1 MBLAC2 SPCS1 TTYH1
# 3                         CHRNA9 CISD2 PBXIP1 TMEM106A
# 4                             COA1 DNAJC11 MCOLN3 SUOX
# ..                                                 ...
# 185  AARSD1 ABCF3 ABTB2 ACADM ACADVL AGGF1 AKAP1 AK...
# 186  ABCC1 ABCF2 ACAD9 ACADM ACSL3 ACVR2B ADAM11 AD...
# 187  AARSD1 AASS ABCC1 ABCF2 ABCF3 ABTB2 ACAD9 ACAD...
# 188  AAR2 AARSD1 AASS AATF ABCC1 ABCF2 ABCF3 ABT1 A...
# 189  AAR2 AARSD1 AASS AATF ABCC1 ABCF2 ABCF3 ABT1 A...
#
#     CD_AnnotatedMembers_SourceDB CD_AnnotatedMembers_Pvalue  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ..                           ...                        ...
# 185                        GO:CC      4.961671990608699E-45
# 186                        GO:CC      7.13113736712789E-211
# 187                        GO:CC    1.7203101692536646E-257
# 188                        CORUM     8.171002669219583E-238
# 189                        CORUM     8.171002669219583E-238
#
#                                 CD_NonAnnotatedMembers CD_MemberList_LogSize  \
# 0                                                  NaN                   2.0
# 1                                                  NaN                   2.0
# 2                                                  NaN                   2.0
# 3                                                  NaN                   2.0
# 4                                                  NaN                   2.0
# ..                                                 ...                   ...
# 185  AARSD1 ABCF3 ABTB2 ACADM ACADVL AGGF1 AKAP1 AK...                 9.145
# 186  ABCC1 ABCF2 ACVR2B ADAM11 ADAM32 ADAM33 ADAM9 ...                 9.834
# 187  AARSD1 AASS ABCC1 ABCF2 ABCF3 ABTB2 ACAD9 ACAD...                10.538
# 188  AAR2 AARSD1 AASS ABCC1 ABCF2 ABCF3 ABT1 ABTB2 ...                10.955
# 189  AAR2 AARSD1 AASS ABCC1 ABCF2 ABCF3 ABT1 ABTB2 ...                10.955
#
#                                   CD_InteractorMembers  \
# 0                                                   []
# 1                                                   []
# 2                                              [CLCC1]
# 3                                                   []
# 4                                            [DNAJC11]
# ..                                                 ...
# 185  [PMPCA, TYSND1, POLA1, PRKACA, USP54, ELOC, PS...
# 186  [TAPT1, ALG11, WFS1, MFGE8, INTS4, SPART, STC2...
# 187  [PMPCA, TYSND1, POLA1, PRKACA, TAPT1, ALG11, W...
# 188  [PMPCA, WFS1, SRP54, AP3B1, ERGIC1, BCS1L, GIG...
# 189  [PMPCA, WFS1, SRP54, AP3B1, ERGIC1, BCS1L, GIG...
#
#      CD_InteractorMemberOverlap
# 0                      0.000000
# 1                      0.000000
# 2                      0.250000
# 3                      0.000000
# 4                      0.250000
# ..                          ...
# 185                    0.212014
# 186                    0.173056
# 187                    0.184264
# 188                    0.156675
# 189                    0.156675
#
# [190 rows x 17 columns]

# %% [markdown]
# ### Add New Attributes to Hierarchy

# %%
# for each of the new columns, iterate setting node attributes
for index, row in node_df.iterrows(): 
    hierarchy_network.set_node_attribute(row["node_id"],
                                         "CD_InteractorMembers", 
                                         row["CD_InteractorMembers"], 
                                         type="list_of_string" )
    hierarchy_network.set_node_attribute(row["node_id"],
                                         "CD_InteractorMemberOverlap", 
                                         row["CD_InteractorMemberOverlap"], 
                                         type="double" )

# %% [markdown]
# ### Save to NDEx

# %%
if my_account == 'enter your username here':
    print('*******WARNING!!!!*******')
    print('Please change the username and password before proceeding')
else:
    upload_message = hierarchy_network.upload_to(my_server, my_account, my_password)
    print(upload_message)
# Out:
# Generating CX
# http://public.ndexbio.org/v2/network/00bc8227-7842-11ea-aaef-0ac135e8bacf

# %%
node_df.to_excel(hierarchy_network.get_name() + " nodes.xlsx")
